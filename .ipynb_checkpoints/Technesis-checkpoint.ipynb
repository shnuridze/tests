# %% [markdown]
# Тестовое задание
#
# Цель
# Вам необходимо обработать сырые данные, поступившие от парсера.
# Описание
# В файле файл с данными две вкладки platform1, platform2. Это данные о
# гостиницах от двух разных платформ в одном регионе.
# Поля
# Поле Описание
# id Идентификатор в БД
# create_time Дата создания
# title Название
# hotel_type_original Тип гостиницы
# city Город
# address Адрес
# rating Рейтинг
# rating_5 Рейтинг по 5-ти бальной шкале
# review_count Количество отзывов
# star_rating Звездность
# rooms_count Количество номеров
# contact_social Контакты соц. сетей
# description Описание
# email email строкой, несколько значений через запятую
# phone телефон строкой, несколько значений через запятую
# website сайты строкой, несколько значений через запятую
# uid Уникальный идентификатор гостиницы на платформе, не
# может быть разным у одной гостиницы, и не может
# повторятся у разных гостиниц, но в рамках одной платформы
#
# parsing_time Время сбора
# lat Широта
#
# Поле Описание
# lon Долгота
#
# Состав данных
#  Записи могут повторятся, и самые актуальные данные идут в конце.
#  Если какое-то поле по конкретной гостинице пустое в последней записи,
# но встречалось ранее, то необходимо его взять из более ранних записей.
#  Поля телефона, email, сайтов могу содержать лишние символы, несколько
# записей и прочее.
#  Формат записи названия, адреса, типа гостиницы отличается в разных
# платформах.
#
# Задача
# 1. Собрать от каждой платформы финальный список гостиниц, в котором по
# каждой гостинице внутри платформы будет только одна запись с самыми
# актуальными и полными данными.
# 2. Почистить данные.
# 3. Поля телефона, email, сайтов распарсить и сохранить как списки в
# одинаковом формате ( address@domen.org, 79234553322, domen.ru)
# 4. Вывести топ 10 по каждой платформе, по параметрам:
# a. больше всего телефонов,
# b. больше всего отзывов.
# 5. Вывести квадрат координат размером 1км на 1км, где больше всего
# гостиниц.
# 6. Задача со *, объединить данные от двух платформ, по критерию, который
# вы придумаете
# a. Вывести все гостиницы, которые есть в платформе 1 и нет в
# платформе 2
# b. Вывести топ 10 гостиниц которые есть в обоих платформах, по
# суммарному количеству отзывов
#
# Требования
# 1. Результат должен быть представлен Jupyter notebook
# 2. Результат должен воспроизводится автоматически и нуля при повторном
# запуске, ручные правки должны быть учтены в коде
# 3. Комментарии приветствуются

# %%
import pandas as pd

# %% [markdown]
# # Загрузка данных

# %%
import requests
from urllib.parse import urlencode

base_url = 'https://cloud-api.yandex.net/v1/disk/public/resources/download?'
public_key = 'https://disk.yandex.ru/d/pnJkHYsLcYF9gQ'  

final_url = base_url + urlencode(dict(public_key=public_key))
response = requests.get(final_url)
download_url = response.json()['href']

# %% [markdown]
# Создаем 2 датафрейма с данными из 2х листов одного файла

# %%
df1 = pd.read_excel(download_url, sheet_name='platform1')
df1.head(2)
# Out:
#       id                 create_time                             title  \
# 0  81842  2023-09-26 14:45:42.910962  Апартаменты Baltia Западный Пляж
# 1  86341  2023-09-26 15:01:55.184815                     Отель Авиатор
#
#   hotel_type_original          city                                address  \
# 0           Apartment  Зеленоградск  улица Приморская, д. 31, Зеленоградск
# 1               Hotel           Уфа             улица Мушникова, д.28, Уфа
#
#    rating  rating_5  review_count  region  ...  rooms_count  contact_social  \
# 0    10.0      5.00             0       2  ...          NaN             NaN
# 1     8.7      4.35             5       2  ...          8.0             NaN
#
#    description  email  phone  website       uid                parsing_time  \
# 0          NaN    NaN    NaN      NaN  10595357  2023-09-26 20:56:02.013106
# 1          NaN    NaN    NaN      NaN   8332081  2023-09-26 20:56:02.013106
#
#          lat        lon
# 0  54.951103  20.456526
# 1  54.783913  56.116150
#
# [2 rows x 21 columns]

# %%
df2 = pd.read_excel(download_url, sheet_name='platfrom2')
df2.head(2)
# Out:
#      id                 create_time              title hotel_type_original  \
# 0  4608  2023-09-14 15:46:07.855977     Уют, гостиница               hotel
# 1  4815  2023-09-14 15:46:48.332492  Гостиница Ашкадар                 NaN
#
#           city                                            address  rating  \
# 0          NaN  Россия, Республика Башкортостан, Аскинский рай...     NaN
# 1  sterlitamak  Россия, Республика Башкортостан, Стерлитамак г...     NaN
#
#    rating_5  review_count  region  ...  rooms_count  contact_social  \
# 0       NaN           NaN       2  ...          5.0             NaN
# 1       NaN           NaN       2  ...          NaN             NaN
#
#   description email phone website                uid  \
# 0         NaN   NaN   NaN     NaN  70000001064499291
# 1         NaN   NaN   NaN     NaN   7600610350202940
#
#                  parsing_time lat  lon
# 0  2023-09-14 22:44:57.013238 NaN  NaN
# 1  2023-09-14 22:44:57.054250 NaN  NaN
#
# [2 rows x 21 columns]

# %% [markdown]
# df = pd.concat([df1,df2],  ignore_index=True)

# %%
def preprocessing(x):
    print(f'таблица имеет следующий вид:')
    display(x.head())
    print('*'*100)
    print(f'таблица имеет {x.shape[0]} сторок и {x.shape[1]} столбцов')
    print('*'*100)
    print(f'в таблице обнаружено дублекатов:{x.duplicated().sum()}')
    print('*'*100)
    print('в таблице обнаружены пропуски в следующих столбцах:')
    display(x.isna().sum())
    print('*'*100)
    print('Эти пропуски составлябт следующее количество в процентах')
    display((x.isna().mean()* 100).round(1))
    print('*'*100)
    print('столбцы имеют следующие типы:')
    display(x.dtypes)
    x.columns = [y.lower().replace(' ', '_') for y in x.columns.values] 
    print('*'*100)
    print('названия столбцов переписаны в нижнем регистре, пробелы заменены на нижнее подчеркивание')
    print('*'*100)
    display(x.info())

# %% [markdown]
# # Обработка данных из первой платформы

# %%
preprocessing(df1)
# Out:
# таблица имеет следующий вид:
#       id                 create_time                             title  \
# 0  81842  2023-09-26 14:45:42.910962  Апартаменты Baltia Западный Пляж
# 1  86341  2023-09-26 15:01:55.184815                     Отель Авиатор
# 2  86420  2023-09-26 15:02:12.005085                         Клеопатра
# 3  86421  2023-09-26 15:02:12.225334                           Татьяна
# 4  85898  2023-09-26 15:00:19.217359                Мини-Отель Чемодан
#
#   hotel_type_original          city                                address  \
# 0           Apartment  Зеленоградск  улица Приморская, д. 31, Зеленоградск
# 1               Hotel           Уфа             улица Мушникова, д.28, Уфа
# 2               Hotel           Уфа       Коммунистическая ул., д. 53, Уфа
# 3               Hotel         Сибай            Учалинская улица, 37, Сибай
# 4          Mini-hotel   Стерлитамак      улица Дружбы, д.28 Д, Стерлитамак
#
#    rating  rating_5  review_count  region  ...  rooms_count  contact_social  \
# 0    10.0      5.00             0       2  ...          NaN             NaN
# 1     8.7      4.35             5       2  ...          8.0             NaN
# 2     6.3      3.15            10       2  ...         15.0             NaN
# 3    10.0      5.00             2       2  ...         15.0             NaN
# 4     8.0      4.00             0       2  ...         23.0             NaN
#
#    description  email  phone  website       uid                parsing_time  \
# 0          NaN    NaN    NaN      NaN  10595357  2023-09-26 20:56:02.013106
# 1          NaN    NaN    NaN      NaN   8332081  2023-09-26 20:56:02.013106
# 2          NaN    NaN    NaN      NaN   7724907  2023-09-26 20:56:02.013106
# 3          NaN    NaN    NaN      NaN   6598197  2023-09-26 20:56:02.013106
# 4          NaN    NaN    NaN      NaN   8622634  2023-09-26 20:56:02.013106
#
#          lat        lon
# 0  54.951103  20.456526
# 1  54.783913  56.116150
# 2  54.726463  55.946445
# 3  52.719230  58.658596
# 4  53.642567  55.932686
#
# [5 rows x 21 columns]
# ****************************************************************************************************
# таблица имеет 5522 сторок и 21 столбцов
# ****************************************************************************************************
# в таблице обнаружено дублекатов:0
# ****************************************************************************************************
# в таблице обнаружены пропуски в следующих столбцах:
# id                        0
# create_time               0
# title                     0
# hotel_type_original       0
# city                      0
# address                   0
# rating                    0
# rating_5                  0
# review_count              0
# region                    0
# star_rating            5211
# rooms_count            4666
# contact_social         5522
# description            5522
# email                  5522
# phone                  5522
# website                5522
# uid                       0
# parsing_time              0
# lat                       0
# lon                       0
# dtype: int64
# ****************************************************************************************************
# Эти пропуски составлябт следующее количество в процентах
# id                       0.0
# create_time              0.0
# title                    0.0
# hotel_type_original      0.0
# city                     0.0
# address                  0.0
# rating                   0.0
# rating_5                 0.0
# review_count             0.0
# region                   0.0
# star_rating             94.4
# rooms_count             84.5
# contact_social         100.0
# description            100.0
# email                  100.0
# phone                  100.0
# website                100.0
# uid                      0.0
# parsing_time             0.0
# lat                      0.0
# lon                      0.0
# dtype: float64
# ****************************************************************************************************
# столбцы имеют следующие типы:
# id                       int64
# create_time             object
# title                   object
# hotel_type_original     object
# city                    object
# address                 object
# rating                 float64
# rating_5               float64
# review_count             int64
# region                   int64
# star_rating            float64
# rooms_count            float64
# contact_social         float64
# description            float64
# email                  float64
# phone                  float64
# website                float64
# uid                      int64
# parsing_time            object
# lat                    float64
# lon                    float64
# dtype: object
# ****************************************************************************************************
# названия столбцов переписаны в нижнем регистре, пробелы заменены на нижнее подчеркивание
# ****************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5522 entries, 0 to 5521
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   5522 non-null   int64
#  1   create_time          5522 non-null   object
#  2   title                5522 non-null   object
#  3   hotel_type_original  5522 non-null   object
#  4   city                 5522 non-null   object
#  5   address              5522 non-null   object
#  6   rating               5522 non-null   float64
#  7   rating_5             5522 non-null   float64
#  8   review_count         5522 non-null   int64
#  9   region               5522 non-null   int64
#  10  star_rating          311 non-null    float64
#  11  rooms_count          856 non-null    float64
#  12  contact_social       0 non-null      float64
#  13  description          0 non-null      float64
#  14  email                0 non-null      float64
#  15  phone                0 non-null      float64
#  16  website              0 non-null      float64
#  17  uid                  5522 non-null   int64
#  18  parsing_time         5522 non-null   object
#  19  lat                  5522 non-null   float64
#  20  lon                  5522 non-null   float64
# dtypes: float64(11), int64(4), object(6)
# memory usage: 906.1+ KB
# None

# %%
len_df1 = len(df1)
len_df1
# Out:
# 5522

# %%
df1.title.nunique()
# Out:
# 5258

# %%
df1.uid.nunique()
# Out:
# 5522

# %%
t = df1.groupby('title')['id'].count().sort_values(ascending=False).reset_index()

# %%
t[t['id']>1].title.nunique()
# Out:
# 175

# %%
t[t['id']>1]
# Out:
#                                      title  id
# 0             Апартаменты Infinity of Days   9
# 1    Апартаменты Apart-Deluxe Легенды Моря   8
# 2                       Апартаменты у Моря   6
# 3          Апартаменты у Королевских Ворот   5
# 4              Апартаменты в центре города   5
# ..                                     ...  ..
# 170        Апартаменты DR Менделеева 128/1   2
# 171                Апартаменты Самый центр   2
# 172             Апартаменты на Аксакова 81   2
# 173              Апартаменты на Дадаева 66   2
# 174    1-к Апартаменты в 2 МИНУТАХ ОТ МОРЯ   2
#
# [175 rows x 2 columns]

# %%
df1.groupby('uid')['id'].count().sort_values(ascending=False).reset_index()
# Out:
#            uid  id
# 0      6292494   1
# 1     10199111   1
# 2     10209402   1
# 3     10209264   1
# 4     10209263   1
# ...        ...  ..
# 5517   9997638   1
# 5518   9997634   1
# 5519   9997602   1
# 5520   9997588   1
# 5521  10847521   1
#
# [5522 rows x 2 columns]

# %%
df1[df1['title']=='Апартаменты на Октябрьской']
# Out:
#          id                 create_time                       title  \
# 1888  82242  2023-09-26 14:47:10.411687  Апартаменты на Октябрьской
# 2459  82819  2023-09-26 14:49:14.652647  Апартаменты на Октябрьской
# 3032  83394  2023-09-26 14:51:19.890314  Апартаменты на Октябрьской
#
#      hotel_type_original          city  \
# 1888           Apartment  Зеленоградск
# 2459           Apartment   Калининград
# 3032           Apartment  Зеленоградск
#
#                                      address  rating  rating_5  review_count  \
# 1888   улица Октябрьская, д.23, Зеленоградск    10.0       5.0             0
# 2459    улица Октябрьская, д.57, Калининград    10.0       5.0             0
# 3032  улица Октябрьская, д. 25, Зеленоградск     9.6       4.8             0
#
#       region  ...  rooms_count  contact_social  description  email  phone  \
# 1888       2  ...          NaN             NaN          NaN    NaN    NaN
# 2459       2  ...          NaN             NaN          NaN    NaN    NaN
# 3032       2  ...          NaN             NaN          NaN    NaN    NaN
#
#       website       uid                parsing_time        lat        lon
# 1888      NaN  10002709  2023-09-26 20:56:02.013106  54.962770  20.484226
# 2459      NaN   8847461  2023-09-26 20:56:02.013106  54.700096  20.519098
# 3032      NaN  10652660  2023-09-26 20:56:02.013106  54.962936  20.483727
#
# [3 rows x 21 columns]

# %%
df1[df1['title']=='Апартаменты на Гагарина']
# Out:
#          id                 create_time                    title  \
# 1408  85520  2023-09-26 14:58:58.383038  Апартаменты на Гагарина
# 1554  81902  2023-09-26 14:45:55.843097  Апартаменты на Гагарина
# 1620  81969  2023-09-26 14:46:10.747489  Апартаменты на Гагарина
#
#      hotel_type_original         city  \
# 1408           Apartment  Калининград
# 1554           Apartment  Калининград
# 1620           Apartment  Калининград
#
#                                                 address  rating  rating_5  \
# 1408           улица Юрия Гагарина, д. 16Б, Калининград     0.0      0.00
# 1554  улица Юрия Гагарина, д. 16В, корп. 3, Калининград     8.6      4.30
# 1620           улица Юрия Гагарина, д. 16Б, Калининград     9.7      4.85
#
#       review_count  region  ...  rooms_count  contact_social  description  \
# 1408             0       2  ...          1.0             NaN          NaN
# 1554             0       2  ...          NaN             NaN          NaN
# 1620             0       2  ...          NaN             NaN          NaN
#
#       email  phone  website      uid                parsing_time        lat  \
# 1408    NaN    NaN      NaN  6848890  2023-09-26 20:56:02.013106  54.718513
# 1554    NaN    NaN      NaN  9993356  2023-09-26 20:56:02.013106  54.719500
# 1620    NaN    NaN      NaN  9996386  2023-09-26 20:56:02.013106  54.718506
#
#             lon
# 1408  20.543240
# 1554  20.544048
# 1620  20.543312
#
# [3 rows x 21 columns]

# %% [markdown]
# Пропустиить значения мы можем только в столбцах `star_rating` и `rooms_count`, поэтому заменяем их на средние значения сгруппированных по названию отелей значениям

# %%
def rooms_count_find(x):
    return df1[df1['title']==x]['rooms_count'].mean()    
df1['rooms_count'] = df1['title'].apply(rooms_count_find)

# %%
def star_rating_find(x):
    return df1[df1['title']==x]['star_rating'].mean()    
df1['star_rating'] = df1['title'].apply(star_rating_find)

# %%
df1[df1['title']=='Апартаменты на Гагарина']
# Out:
#          id                 create_time                    title  \
# 1408  85520  2023-09-26 14:58:58.383038  Апартаменты на Гагарина
# 1554  81902  2023-09-26 14:45:55.843097  Апартаменты на Гагарина
# 1620  81969  2023-09-26 14:46:10.747489  Апартаменты на Гагарина
#
#      hotel_type_original         city  \
# 1408           Apartment  Калининград
# 1554           Apartment  Калининград
# 1620           Apartment  Калининград
#
#                                                 address  rating  rating_5  \
# 1408           улица Юрия Гагарина, д. 16Б, Калининград     0.0      0.00
# 1554  улица Юрия Гагарина, д. 16В, корп. 3, Калининград     8.6      4.30
# 1620           улица Юрия Гагарина, д. 16Б, Калининград     9.7      4.85
#
#       review_count  region  ...  rooms_count  contact_social  description  \
# 1408             0       2  ...          1.0             NaN          NaN
# 1554             0       2  ...          1.0             NaN          NaN
# 1620             0       2  ...          1.0             NaN          NaN
#
#       email  phone  website      uid                parsing_time        lat  \
# 1408    NaN    NaN      NaN  6848890  2023-09-26 20:56:02.013106  54.718513
# 1554    NaN    NaN      NaN  9993356  2023-09-26 20:56:02.013106  54.719500
# 1620    NaN    NaN      NaN  9996386  2023-09-26 20:56:02.013106  54.718506
#
#             lon
# 1408  20.543240
# 1554  20.544048
# 1620  20.543312
#
# [3 rows x 21 columns]

# %%
len(df1)
# Out:
# 5522

# %%
df1 = df1.drop_duplicates(subset=['title'], keep='last', ignore_index=True)

# %%
df1[df1['title']=='Апартаменты на Гагарина']
# Out:
#          id                 create_time                    title  \
# 1522  81969  2023-09-26 14:46:10.747489  Апартаменты на Гагарина
#
#      hotel_type_original         city  \
# 1522           Apartment  Калининград
#
#                                        address  rating  rating_5  \
# 1522  улица Юрия Гагарина, д. 16Б, Калининград     9.7      4.85
#
#       review_count  region  ...  rooms_count  contact_social  description  \
# 1522             0       2  ...          1.0             NaN          NaN
#
#       email  phone  website      uid                parsing_time        lat  \
# 1522    NaN    NaN      NaN  9996386  2023-09-26 20:56:02.013106  54.718506
#
#             lon
# 1522  20.543312
#
# [1 rows x 21 columns]

# %%
len(df1)
# Out:
# 5258

# %%
df1.title.nunique()
# Out:
# 5258

# %%
len_df1 - len(df1)
# Out:
# 264

# %%
t = df1.groupby('title')['id'].count().sort_values(ascending=False).reset_index()

# %%
t[t['id']>1]
# Out:
# Empty DataFrame
# Columns: [title, id]
# Index: []

# %% [markdown]
# Все имена отелей взятые из первой платформы уникальны и не повторяются. Было удалено 264 дублируемых записей

# %%
xx = df1.sort_values('review_count',ascending=False).title.head(10).reset_index()
xx.title.unique()
# Out:
# array(['Radisson Blu Hotel Kaliningrad', 'AZIMUT Сити Отель Уфа',
#        'Отель Кайзерхоф (Kaiserhof)', 'Отель Ibis Калининград Центр',
#        'Hilton Garden Inn Ufa Riverside', 'Отель АМАКС Сити-отель',
#        'Отель Hampton by Hilton Уфа',
#        'Гостиничный Комплекс Президент Отель',
#        'Гостиница Мартон Палас Калининград', 'Гостиница "Шкиперская"'],
#       dtype=object)

# %%
df1[['title', 'review_count']].sort_values('review_count',ascending=False).head(10)
# Out:
#                                      title  review_count
# 1631        Radisson Blu Hotel Kaliningrad          1201
# 8                    AZIMUT Сити Отель Уфа           988
# 1709           Отель Кайзерхоф (Kaiserhof)           930
# 5221          Отель Ibis Калининград Центр           837
# 5          Hilton Garden Inn Ufa Riverside           616
# 11                  Отель АМАКС Сити-отель           540
# 6              Отель Hampton by Hilton Уфа           460
# 180   Гостиничный Комплекс Президент Отель           414
# 5218    Гостиница Мартон Палас Калининград           334
# 1483                Гостиница "Шкиперская"           302

# %% [markdown]
# топ 10 гостиниц с первой платформы по количеству отзывов

# %% [markdown]
# топ 10 гостиниц из первой платформы по количетву телефонов нет смысла искать, так как у первой платформы в номерах телефонов 100 % пропусков

# %% [markdown]
# # Обработка данных из второй платформы

# %%
preprocessing(df2)
# Out:
# таблица имеет следующий вид:
#       id                 create_time                  title  \
# 0   4608  2023-09-14 15:46:07.855977         Уют, гостиница
# 1   4815  2023-09-14 15:46:48.332492      Гостиница Ашкадар
# 2   4750  2023-09-14 15:46:35.659931  Островок, база отдыха
# 3   4786  2023-09-14 15:46:42.672665     Ардан, база отдыха
# 4  16310  2023-09-15 11:56:48.785266              Гостиница
#
#   hotel_type_original         city  \
# 0               hotel          NaN
# 1                 NaN  sterlitamak
# 2          hotel_rest          NaN
# 3          hotel_rest          NaN
# 4               hotel    beloretsk
#
#                                              address  rating  rating_5  \
# 0  Россия, Республика Башкортостан, Аскинский рай...     NaN       NaN
# 1  Россия, Республика Башкортостан, Стерлитамак г...     NaN       NaN
# 2  Россия, Республика Башкортостан, Гафурийский р...     NaN       NaN
# 3  Россия, Республика Башкортостан, Баймакский ра...     NaN       NaN
# 4  Россия, Республика Башкортостан, Белорецкий ра...     NaN       NaN
#
#    review_count  region  ...  rooms_count  contact_social description email  \
# 0           NaN       2  ...          5.0             NaN         NaN   NaN
# 1           NaN       2  ...          NaN             NaN         NaN   NaN
# 2           NaN       2  ...          NaN             NaN         NaN   NaN
# 3           NaN       2  ...          NaN             NaN         NaN   NaN
# 4           NaN       2  ...          NaN             NaN         NaN   NaN
#
#   phone website                uid                parsing_time        lat  \
# 0   NaN     NaN  70000001064499291  2023-09-14 22:44:57.013238        NaN
# 1   NaN     NaN   7600610350202940  2023-09-14 22:44:57.054250        NaN
# 2   NaN     NaN  70000001076845858  2023-09-14 22:44:57.043234        NaN
# 3   NaN     NaN  70000001075946655  2023-09-14 22:44:57.049244        NaN
# 4   NaN     NaN  70000001031030911  2023-09-15 18:55:23.191778  53.969912
#
#          lon
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4  58.400557
#
# [5 rows x 21 columns]
# ****************************************************************************************************
# таблица имеет 2767 сторок и 21 столбцов
# ****************************************************************************************************
# в таблице обнаружено дублекатов:0
# ****************************************************************************************************
# в таблице обнаружены пропуски в следующих столбцах:
# id                        0
# create_time               0
# title                     0
# hotel_type_original      20
# city                   1145
# address                   0
# rating                  648
# rating_5                648
# review_count            648
# region                    0
# star_rating            2176
# rooms_count            1105
# contact_social         2261
# description            2570
# email                  2700
# phone                  1691
# website                2033
# uid                       0
# parsing_time              0
# lat                     573
# lon                     573
# dtype: int64
# ****************************************************************************************************
# Эти пропуски составлябт следующее количество в процентах
# id                      0.0
# create_time             0.0
# title                   0.0
# hotel_type_original     0.7
# city                   41.4
# address                 0.0
# rating                 23.4
# rating_5               23.4
# review_count           23.4
# region                  0.0
# star_rating            78.6
# rooms_count            39.9
# contact_social         81.7
# description            92.9
# email                  97.6
# phone                  61.1
# website                73.5
# uid                     0.0
# parsing_time            0.0
# lat                    20.7
# lon                    20.7
# dtype: float64
# ****************************************************************************************************
# столбцы имеют следующие типы:
# id                       int64
# create_time             object
# title                   object
# hotel_type_original     object
# city                    object
# address                 object
# rating                 float64
# rating_5               float64
# review_count           float64
# region                   int64
# star_rating            float64
# rooms_count            float64
# contact_social          object
# description             object
# email                   object
# phone                   object
# website                 object
# uid                      int64
# parsing_time            object
# lat                    float64
# lon                    float64
# dtype: object
# ****************************************************************************************************
# названия столбцов переписаны в нижнем регистре, пробелы заменены на нижнее подчеркивание
# ****************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2767 entries, 0 to 2766
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   2767 non-null   int64
#  1   create_time          2767 non-null   object
#  2   title                2767 non-null   object
#  3   hotel_type_original  2747 non-null   object
#  4   city                 1622 non-null   object
#  5   address              2767 non-null   object
#  6   rating               2119 non-null   float64
#  7   rating_5             2119 non-null   float64
#  8   review_count         2119 non-null   float64
#  9   region               2767 non-null   int64
#  10  star_rating          591 non-null    float64
#  11  rooms_count          1662 non-null   float64
#  12  contact_social       506 non-null    object
#  13  description          197 non-null    object
#  14  email                67 non-null     object
#  15  phone                1076 non-null   object
#  16  website              734 non-null    object
#  17  uid                  2767 non-null   int64
#  18  parsing_time         2767 non-null   object
#  19  lat                  2194 non-null   float64
#  20  lon                  2194 non-null   float64
# dtypes: float64(7), int64(3), object(11)
# memory usage: 454.1+ KB
# None

# %%
len_df2 = len(df2)
len_df2
# Out:
# 2767

# %%
df2.title.nunique()
# Out:
# 483

# %%
df2.uid.nunique()
# Out:
# 549

# %%
t = df2.groupby('title')['id'].count().sort_values(ascending=False).reset_index()

# %%
t[t['id']>1].title.nunique()
# Out:
# 483

# %% [markdown]
# Данные о всех гостиницах дублируются

# %%
t[t['id']>1]
# Out:
#                        title  id
# 0                  Гостиница  65
# 1             Уют, гостиница  60
# 2                 Мини-отель  20
# 3             Автобус в лесу  20
# 4         Евразия, гостиница  20
# ..                       ...  ..
# 478       Восток1453, мотель   5
# 479    Восток1453, гостиница   5
# 480         ВолнаСити, отель   5
# 481         Воздух, глэмпинг   5
# 482  на Мраткино, мини-отель   5
#
# [483 rows x 2 columns]

# %%
df2[df2['title']=='Любизар, гостиница']
# Out:
#          id                 create_time               title  \
# 278    4528  2023-09-14 15:45:52.103983  Любизар, гостиница
# 832   16139  2023-09-15 11:56:16.001027  Любизар, гостиница
# 1382  67712  2023-09-29 15:26:40.837023  Любизар, гостиница
# 1851  29712  2023-09-15 16:49:45.725057  Любизар, гостиница
# 2485  49567  2023-09-19 21:45:04.847796  Любизар, гостиница
#
#      hotel_type_original city  \
# 278                hotel  NaN
# 832                hotel  NaN
# 1382               hotel  NaN
# 1851               hotel  NaN
# 2485               hotel  NaN
#
#                                                 address  rating  rating_5  \
# 278   Россия, Республика Башкортостан, Гафурийский р...     3.3       3.3
# 832   Россия, Республика Башкортостан, Гафурийский р...     3.3       3.3
# 1382  Россия, Республика Башкортостан, Гафурийский р...     3.3       3.3
# 1851  Россия, Республика Башкортостан, Гафурийский р...     3.3       3.3
# 2485  Россия, Республика Башкортостан, Гафурийский р...     3.3       3.3
#
#       review_count  region  ...  rooms_count  \
# 278            4.0       2  ...         15.0
# 832            4.0       2  ...         15.0
# 1382           4.0       2  ...         15.0
# 1851           4.0       2  ...         15.0
# 2485           4.0       2  ...         15.0
#
#                                          contact_social description email  \
# 278                                                 NaN         NaN   NaN
# 832                                                 NaN         NaN   NaN
# 1382  [{"social": "vk", "contact": "https://vk.com/c...         NaN   NaN
# 1851                                                NaN         NaN   NaN
# 2485  [{"social": "vk", "contact": "https://vk.com/c...         NaN   NaN
#
#              phone        website                uid  \
# 278            NaN            NaN  70000001062965360
# 832            NaN            NaN  70000001062965360
# 1382  +73474026959            NaN  70000001062965360
# 1851           NaN            NaN  70000001062965360
# 2485  +73474026959  Забронировать  70000001062965360
#
#                     parsing_time        lat        lon
# 278   2023-09-14 22:44:56.995231        NaN        NaN
# 832   2023-09-15 18:55:23.190778  53.892723  56.467748
# 1382  2023-09-29 22:24:07.344402  53.892723  56.467748
# 1851  2023-09-15 23:48:32.440373  53.892723  56.467748
# 2485  2023-09-20 04:42:37.036551  53.892723  56.467748
#
# [5 rows x 21 columns]

# %%
df2[df2['title']=='Любизар, гостиница'].sort_values(['contact_social', 'email', 'phone', 'website',  'description', 'lat', 'lon'], ascending=False)
# Out:
#          id                 create_time               title  \
# 2485  49567  2023-09-19 21:45:04.847796  Любизар, гостиница
# 1382  67712  2023-09-29 15:26:40.837023  Любизар, гостиница
# 832   16139  2023-09-15 11:56:16.001027  Любизар, гостиница
# 1851  29712  2023-09-15 16:49:45.725057  Любизар, гостиница
# 278    4528  2023-09-14 15:45:52.103983  Любизар, гостиница
#
#      hotel_type_original city  \
# 2485               hotel  NaN
# 1382               hotel  NaN
# 832                hotel  NaN
# 1851               hotel  NaN
# 278                hotel  NaN
#
#                                                 address  rating  rating_5  \
# 2485  Россия, Республика Башкортостан, Гафурийский р...     3.3       3.3
# 1382  Россия, Республика Башкортостан, Гафурийский р...     3.3       3.3
# 832   Россия, Республика Башкортостан, Гафурийский р...     3.3       3.3
# 1851  Россия, Республика Башкортостан, Гафурийский р...     3.3       3.3
# 278   Россия, Республика Башкортостан, Гафурийский р...     3.3       3.3
#
#       review_count  region  ...  rooms_count  \
# 2485           4.0       2  ...         15.0
# 1382           4.0       2  ...         15.0
# 832            4.0       2  ...         15.0
# 1851           4.0       2  ...         15.0
# 278            4.0       2  ...         15.0
#
#                                          contact_social description email  \
# 2485  [{"social": "vk", "contact": "https://vk.com/c...         NaN   NaN
# 1382  [{"social": "vk", "contact": "https://vk.com/c...         NaN   NaN
# 832                                                 NaN         NaN   NaN
# 1851                                                NaN         NaN   NaN
# 278                                                 NaN         NaN   NaN
#
#              phone        website                uid  \
# 2485  +73474026959  Забронировать  70000001062965360
# 1382  +73474026959            NaN  70000001062965360
# 832            NaN            NaN  70000001062965360
# 1851           NaN            NaN  70000001062965360
# 278            NaN            NaN  70000001062965360
#
#                     parsing_time        lat        lon
# 2485  2023-09-20 04:42:37.036551  53.892723  56.467748
# 1382  2023-09-29 22:24:07.344402  53.892723  56.467748
# 832   2023-09-15 18:55:23.190778  53.892723  56.467748
# 1851  2023-09-15 23:48:32.440373  53.892723  56.467748
# 278   2023-09-14 22:44:56.995231        NaN        NaN
#
# [5 rows x 21 columns]

# %%
df2 = df2.sort_values(['contact_social', 'email', 'phone', 'website',  'description', 'lat', 'lon'], ascending=False)

# %%
len(df2)
# Out:
# 2767

# %%
df2 = df2.drop_duplicates(subset=['title','address'], keep='first', ignore_index=True)

# %%
len(df2)
# Out:
# 549

# %%
t = df2.groupby(['title', 'city'])['id'].count().sort_values(ascending=False).reset_index()

# %%
t[t['id']>1].title.nunique()
# Out:
# 19

# %%
t[t['id']>1]
# Out:
#                                 title          city  id
# 0                          Мини-отель           ufa   4
# 1                By Richotels, хостел           ufa   3
# 2                           Гостиница           ufa   3
# 3                  Вершина, гостиница  magnitogorsk   3
# 4                  Уютель, мини-отель           ufa   3
# 5                        Гостевой дом           ufa   2
# 6                           Гостиница     beloretsk   2
# 7              Добрый день, гостиница           ufa   2
# 8                   Main room, хостел           ufa   2
# 9                        Гранд, отель   oktyabrskiy   2
# 10                  Молодость, студия           ufa   2
# 11  Роза ветров, гостиничный комплекс           ufa   2
# 12                     Ной, гостиница           ufa   2
# 13   Альпийский, гостиничный комплекс           ufa   2
# 14                Белорецк, гостиница     beloretsk   2
# 15                    Аристоль, отель           ufa   2
# 16                     Уют, гостиница           ufa   2
# 17                       Отдых, отель           ufa   2
# 18                 Евразия, гостиница           ufa   2
# 19                   Alpen hof, отель  magnitogorsk   2

# %%
df2[df2['title']=='Вершина, гостиница']
# Out:
#         id                 create_time               title  \
# 18   49428  2023-09-19 21:44:30.231997  Вершина, гостиница
# 544  16250  2023-09-15 11:56:37.321212  Вершина, гостиница
# 545  16356  2023-09-15 11:56:57.629864  Вершина, гостиница
#
#     hotel_type_original          city  \
# 18                hotel  magnitogorsk
# 544               hotel  magnitogorsk
# 545               hotel  magnitogorsk
#
#                                                address  rating  rating_5  \
# 18   Россия, Республика Башкортостан, Абзелиловский...     4.9       4.9
# 544  Россия, Республика Башкортостан, Абзелиловский...     5.0       5.0
# 545  Россия, Республика Башкортостан, Абзелиловский...     5.0       5.0
#
#      review_count  region  ...  rooms_count  \
# 18           49.0       2  ...          NaN
# 544           1.0       2  ...          NaN
# 545           1.0       2  ...          NaN
#
#                                         contact_social description email  \
# 18   [{"social": "vk", "contact": "https://vk.com/v...         NaN   NaN
# 544                                                NaN         NaN   NaN
# 545                                                NaN         NaN   NaN
#
#                          phone            website                uid  \
# 18   +79000868687, 88002016652  vershinabannoe.ru  70000001052317885
# 544                        NaN                NaN  70000001066187204
# 545                        NaN                NaN  70000001066187103
#
#                    parsing_time        lat        lon
# 18   2023-09-20 04:42:00.302992  53.586043  58.597512
# 544  2023-09-15 18:55:23.191778  53.612514  58.624162
# 545  2023-09-15 18:55:23.192779  53.611882  58.610292
#
# [3 rows x 21 columns]

# %%
df2 = df2.sort_values(['contact_social', 'email', 'phone', 'website',  'description', 'lat', 'lon'], ascending=False)

# %%
df2[df2['title']=='Вершина, гостиница']
# Out:
#         id                 create_time               title  \
# 18   49428  2023-09-19 21:44:30.231997  Вершина, гостиница
# 544  16250  2023-09-15 11:56:37.321212  Вершина, гостиница
# 545  16356  2023-09-15 11:56:57.629864  Вершина, гостиница
#
#     hotel_type_original          city  \
# 18                hotel  magnitogorsk
# 544               hotel  magnitogorsk
# 545               hotel  magnitogorsk
#
#                                                address  rating  rating_5  \
# 18   Россия, Республика Башкортостан, Абзелиловский...     4.9       4.9
# 544  Россия, Республика Башкортостан, Абзелиловский...     5.0       5.0
# 545  Россия, Республика Башкортостан, Абзелиловский...     5.0       5.0
#
#      review_count  region  ...  rooms_count  \
# 18           49.0       2  ...          NaN
# 544           1.0       2  ...          NaN
# 545           1.0       2  ...          NaN
#
#                                         contact_social description email  \
# 18   [{"social": "vk", "contact": "https://vk.com/v...         NaN   NaN
# 544                                                NaN         NaN   NaN
# 545                                                NaN         NaN   NaN
#
#                          phone            website                uid  \
# 18   +79000868687, 88002016652  vershinabannoe.ru  70000001052317885
# 544                        NaN                NaN  70000001066187204
# 545                        NaN                NaN  70000001066187103
#
#                    parsing_time        lat        lon
# 18   2023-09-20 04:42:00.302992  53.586043  58.597512
# 544  2023-09-15 18:55:23.191778  53.612514  58.624162
# 545  2023-09-15 18:55:23.192779  53.611882  58.610292
#
# [3 rows x 21 columns]

# %%
len(df2)
# Out:
# 549

# %%
df2 = df2.drop_duplicates(subset=['title', 'city'], keep='first', ignore_index=True)

# %%
len(df2)
# Out:
# 500

# %%
df2.groupby('title')['id'].count().sort_values(ascending=False).reset_index()
# Out:
#                        title  id
# 0                  Гостиница   4
# 1             Уют, гостиница   3
# 2         Евразия, гостиница   3
# 3         Престиж, гостиница   2
# 4          Ель, гостевой дом   2
# ..                       ...  ..
# 478      Виктория, гостиница   1
# 479                    Визит   1
# 480               Вечный зов   1
# 481         Вечер, гостиница   1
# 482  на Мраткино, мини-отель   1
#
# [483 rows x 2 columns]

# %%
df2[df2['title']=='Ель, гостевой дом']
# Out:
#         id                 create_time              title hotel_type_original  \
# 132  49359  2023-09-19 21:44:11.851627  Ель, гостевой дом               hotel
# 402  49820  2023-09-19 21:46:04.496815  Ель, гостевой дом               hotel
#
#              city                                            address  rating  \
# 132           ufa  Россия, Республика Башкортостан, Уфимский райо...     5.0
# 402  magnitogorsk  Россия, Республика Башкортостан, Абзелиловский...     NaN
#
#      rating_5  review_count  region  ...  rooms_count  \
# 132       5.0         165.0       2  ...          7.0
# 402       NaN           NaN       2  ...          8.0
#
#                                         contact_social description email  \
# 132  [{"social": "vk", "contact": "https://vk.com/d...         NaN   NaN
# 402                                                NaN         NaN   NaN
#
#                           phone              website                uid  \
# 132  +79871349915, +79174127908            firufa.ru  70000001026567610
# 402                +79128071212  Забронировать номер  70000001047414613
#
#                    parsing_time        lat        lon
# 132  2023-09-20 04:41:42.416198  54.605298  55.964605
# 402  2023-09-20 04:43:43.494296  53.607912  58.617980
#
# [2 rows x 21 columns]

# %%
len_df2 - len(df2)
# Out:
# 2267

# %% [markdown]
# Есть дублекаты в названии гостиниц, но данные гостиници из разных городов, имеют разный адрес

# %% [markdown]
# Всего удалено 2267 дублекатов

# %%
df2['phone'] = df2['phone'].str.replace('+', '', regex=True)

# %%
df2['website'] = df2['website'].str.replace('www.', '', regex=True).replace('https://', '', regex=True)

# %%
def split_fone(x):
    x = str(x)
    return x.split(',')
df2['phone'] = df2['phone'].apply(split_fone)

# %%
def count_fone(x):
    x = str(x)
    x = x.split(',')
    return len(x)
df2['len_phone'] = df2['phone'].apply(count_fone)

# %%
df2['email'] = df2['email'].apply(split_fone)

# %%
df2.sort_values('len_phone',ascending=False).title.head(10)
# Out:
# 158                   Ивкор, база отдыха
# 64                   Ясная поляна, отель
# 375              Добр здравич, гостиница
# 212             Green home, гостевой дом
# 211                   Шале поляна, отель
# 217             Межгорье, мини-гостиница
# 462    Аэропорт aeropot hotel, гостиница
# 308                 Орленок, апарт-отель
# 15                     Vgosti, гостиница
# 283                   Сказка, мини-отель
# Name: title, dtype: object

# %%
xx = df2.sort_values('len_phone',ascending=False).head(10).reset_index()
xx[['title', 'len_phone']]
# Out:
#                                title  len_phone
# 0                 Ивкор, база отдыха          5
# 1                Ясная поляна, отель          4
# 2            Добр здравич, гостиница          4
# 3           Green home, гостевой дом          4
# 4                 Шале поляна, отель          4
# 5           Межгорье, мини-гостиница          4
# 6  Аэропорт aeropot hotel, гостиница          4
# 7               Орленок, апарт-отель          4
# 8                  Vgosti, гостиница          4
# 9                 Сказка, мини-отель          4

# %%
xx[['title', 'len_phone']].title.unique()
# Out:
# array(['Ивкор, база отдыха', 'Ясная поляна, отель',
#        'Добр здравич, гостиница', 'Green home, гостевой дом',
#        'Шале поляна, отель', 'Межгорье, мини-гостиница',
#        'Аэропорт aeropot hotel, гостиница', 'Орленок, апарт-отель',
#        'Vgosti, гостиница', 'Сказка, мини-отель'], dtype=object)

# %% [markdown]
# топ 10 гостиниц со второй платформы по номерам телефонов

# %%
df2.sort_values('review_count',ascending=False).title.head(10)
# Out:
# 113         Hilton Garden Inn Ufa Riverside, отель
# 50                  Башкирия, гостиничный комплекс
# 114                   Hampton by hilton Ufa, отель
# 191                 Урал тау, гостиничный комплекс
# 409                          AZIMUT Сити Отель Уфа
# 196                    Амакс Сити-отель, гостиница
# 60           Президент отель, гостиничный комплекс
# 39     Sheratonplaza Ufa Congress Hotel, гостиница
# 14                                ВолнаСити, отель
# 147                    Свояк, гостиничный комплекс
# Name: title, dtype: object

# %%
xx = df2.sort_values('review_count',ascending=False).head(10).reset_index()
xx[['title', 'review_count']]
# Out:
#                                          title  review_count
# 0       Hilton Garden Inn Ufa Riverside, отель         823.0
# 1               Башкирия, гостиничный комплекс         780.0
# 2                 Hampton by hilton Ufa, отель         451.0
# 3               Урал тау, гостиничный комплекс         416.0
# 4                        AZIMUT Сити Отель Уфа         386.0
# 5                  Амакс Сити-отель, гостиница         358.0
# 6        Президент отель, гостиничный комплекс         341.0
# 7  Sheratonplaza Ufa Congress Hotel, гостиница         240.0
# 8                             ВолнаСити, отель         232.0
# 9                  Свояк, гостиничный комплекс         222.0

# %%
xx[['title', 'review_count']].title.unique()
# Out:
# array(['Hilton Garden Inn Ufa Riverside, отель',
#        'Башкирия, гостиничный комплекс', 'Hampton by hilton Ufa, отель',
#        'Урал тау, гостиничный комплекс', 'AZIMUT Сити Отель Уфа',
#        'Амакс Сити-отель, гостиница',
#        'Президент отель, гостиничный комплекс',
#        'Sheratonplaza Ufa Congress Hotel, гостиница', 'ВолнаСити, отель',
#        'Свояк, гостиничный комплекс'], dtype=object)

# %% [markdown]
# топ 10 гостиниц со второй платформы по количеству отзывов

# %%
df = pd.concat([df1,df2], ignore_index=True)

# %%
df
# Out:
#          id                 create_time                             title  \
# 0     81842  2023-09-26 14:45:42.910962  Апартаменты Baltia Западный Пляж
# 1     86341  2023-09-26 15:01:55.184815                     Отель Авиатор
# 2     86420  2023-09-26 15:02:12.005085                         Клеопатра
# 3     86421  2023-09-26 15:02:12.225334                           Татьяна
# 4     85898  2023-09-26 15:00:19.217359                Мини-Отель Чемодан
# ...     ...                         ...                               ...
# 5753  16407  2023-09-15 11:57:07.426194     Культамак, туристическая база
# 5754  16426  2023-09-15 11:57:11.066009                 Гостиница Ашкадар
# 5755  16146  2023-09-15 11:56:17.349221                  Бабай, гостиница
# 5756  16314  2023-09-15 11:56:49.545903                    Уют, гостиница
# 5757  16235  2023-09-15 11:56:34.433299                Березка, гостиница
#
#      hotel_type_original          city  \
# 0              Apartment  Зеленоградск
# 1                  Hotel           Уфа
# 2                  Hotel           Уфа
# 3                  Hotel         Сибай
# 4             Mini-hotel   Стерлитамак
# ...                  ...           ...
# 5753          hotel_rest           NaN
# 5754                 NaN   sterlitamak
# 5755               hotel           NaN
# 5756               hotel      kumertau
# 5757                 NaN           NaN
#
#                                                 address  rating  rating_5  \
# 0                 улица Приморская, д. 31, Зеленоградск    10.0      5.00
# 1                            улица Мушникова, д.28, Уфа     8.7      4.35
# 2                      Коммунистическая ул., д. 53, Уфа     6.3      3.15
# 3                           Учалинская улица, 37, Сибай    10.0      5.00
# 4                     улица Дружбы, д.28 Д, Стерлитамак     8.0      4.00
# ...                                                 ...     ...       ...
# 5753  Россия, Республика Башкортостан, Гафурийский р...     NaN       NaN
# 5754  Россия, Республика Башкортостан, Стерлитамак г...     NaN       NaN
# 5755  Россия, Республика Башкортостан, Кумертау горо...     1.0      1.00
# 5756  Россия, Республика Башкортостан, Кумертау горо...     5.0      5.00
# 5757  Россия, Республика Башкортостан, Зианчуринский...     NaN       NaN
#
#       review_count  region  ...  contact_social  description  email  phone  \
# 0              0.0       2  ...             NaN          NaN    NaN    NaN
# 1              5.0       2  ...             NaN          NaN    NaN    NaN
# 2             10.0       2  ...             NaN          NaN    NaN    NaN
# 3              2.0       2  ...             NaN          NaN    NaN    NaN
# 4              0.0       2  ...             NaN          NaN    NaN    NaN
# ...            ...     ...  ...             ...          ...    ...    ...
# 5753           NaN       2  ...             NaN          NaN  [nan]  [nan]
# 5754           NaN       2  ...             NaN          NaN  [nan]  [nan]
# 5755          22.0       2  ...             NaN          NaN  [nan]  [nan]
# 5756           1.0       2  ...             NaN          NaN  [nan]  [nan]
# 5757           NaN       2  ...             NaN          NaN  [nan]  [nan]
#
#      website                uid                parsing_time        lat  \
# 0        NaN           10595357  2023-09-26 20:56:02.013106  54.951103
# 1        NaN            8332081  2023-09-26 20:56:02.013106  54.783913
# 2        NaN            7724907  2023-09-26 20:56:02.013106  54.726463
# 3        NaN            6598197  2023-09-26 20:56:02.013106  52.719230
# 4        NaN            8622634  2023-09-26 20:56:02.013106  53.642567
# ...      ...                ...                         ...        ...
# 5753     NaN  70000001078906834  2023-09-15 18:55:23.192779  53.947493
# 5754     NaN   7600610350202940  2023-09-15 18:55:23.193779  53.638674
# 5755     NaN  70000001078566897  2023-09-15 18:55:23.190778  52.842008
# 5756     NaN  70000001036752640  2023-09-15 18:55:23.191778  52.783095
# 5757     NaN  70000001076190081  2023-09-15 18:55:23.191778  52.189668
#
#             lon  len_phone
# 0     20.456526        NaN
# 1     56.116150        NaN
# 2     55.946445        NaN
# 3     58.658596        NaN
# 4     55.932686        NaN
# ...         ...        ...
# 5753  57.061174        1.0
# 5754  55.937977        1.0
# 5755  55.917853        1.0
# 5756  55.781158        1.0
# 5757  56.593384        1.0
#
# [5758 rows x 22 columns]

# %%
def test(x,y):
    return [x, y]
df['test'] = df.apply(lambda x: test(x.lat, x.lon), axis=1)

# %%
(50.7207-50.7117)/2
# Out:
# 0.0045000000000001705

# %%
(20.4524-20.4369)/2
# Out:
# 0.007749999999999702

# %%
def position(x):
    nums = 0
    for index, item in enumerate(df['test']):
        if item[0] <= (x[0]+0.0045) and item[0] >= (x[0]-0.0045) and item[1] <= (x[1]+0.0077) and item[1] >= (x[1]-0.0077):
            nums+=1
    return nums
df['count_gost'] = df['test'].apply(position)
df.sort_values('count_gost',ascending=False).head(60)
# Out:
#          id                 create_time  \
# 2344  82873  2023-09-26 14:49:26.201114
# 3525  84132  2023-09-26 14:54:00.667660
# 1367  81790  2023-09-26 14:45:31.462609
# 4078  84709  2023-09-26 14:56:05.088718
# 4968  85637  2023-09-26 14:59:22.662617
# 2770  83325  2023-09-26 14:51:04.814362
# 2675  83225  2023-09-26 14:50:42.970196
# 2318  82847  2023-09-26 14:49:20.669013
# 1937  82429  2023-09-26 14:47:50.675915
# 1375  81799  2023-09-26 14:45:33.406780
# 4680  85340  2023-09-26 14:58:20.698811
# 4689  85349  2023-09-26 14:58:22.574347
# 2382  82911  2023-09-26 14:49:34.221180
# 3731  84347  2023-09-26 14:54:47.148507
# 3010  83589  2023-09-26 14:52:02.891191
# 4660  85319  2023-09-26 14:58:16.289806
# 3109  83695  2023-09-26 14:52:26.086682
# 2445  82978  2023-09-26 14:49:48.596795
# 2918  83489  2023-09-26 14:51:40.813298
# 4759  85422  2023-09-26 14:58:37.790684
# 1545  81994  2023-09-26 14:46:16.167432
# 2667  83217  2023-09-26 14:50:41.285996
# 3440  84043  2023-09-26 14:53:41.215826
# 3293  83886  2023-09-26 14:53:07.431390
# 4459  85107  2023-09-26 14:57:30.942051
# 1531  81980  2023-09-26 14:46:13.171412
# 2374  82903  2023-09-26 14:49:32.545162
# 5235  81774  2023-09-26 14:45:27.974875
# 3739  84357  2023-09-26 14:54:49.248806
# 1700  82166  2023-09-26 14:46:53.723747
# 1906  82396  2023-09-26 14:47:43.512065
# 2201  82718  2023-09-26 14:48:52.925247
# 57    82006  2023-09-26 14:46:18.767280
# 2266  82789  2023-09-26 14:49:08.241246
# 3673  84289  2023-09-26 14:54:34.552454
# 3631  84244  2023-09-26 14:54:24.796457
# 1743  82217  2023-09-26 14:47:04.903582
# 2690  83240  2023-09-26 14:50:46.253822
# 1683  82146  2023-09-26 14:46:49.343100
# 4143  84778  2023-09-26 14:56:20.513448
# 1595  82050  2023-09-26 14:46:28.303938
# 3680  84296  2023-09-26 14:54:36.040616
# 2328  82857  2023-09-26 14:49:22.797442
# 3210  83801  2023-09-26 14:52:49.126782
# 2551  83092  2023-09-26 14:50:13.657599
# 2048  82551  2023-09-26 14:48:16.924570
# 3541  84148  2023-09-26 14:54:04.104064
# 3477  84081  2023-09-26 14:53:49.551908
# 4741  85401  2023-09-26 14:58:33.398606
# 1778  82258  2023-09-26 14:47:13.891638
# 4473  85121  2023-09-26 14:57:33.999310
# 2840  83402  2023-09-26 14:51:21.674231
# 4760  85423  2023-09-26 14:58:37.998898
# 3687  84303  2023-09-26 14:54:37.572732
# 4142  84777  2023-09-26 14:56:20.273506
# 3618  84230  2023-09-26 14:54:21.732835
# 4751  85411  2023-09-26 14:58:35.471042
# 3382  83979  2023-09-26 14:53:27.379988
# 2153  82664  2023-09-26 14:48:41.260319
# 3082  83667  2023-09-26 14:52:19.906654
#
#                                                   title  hotel_type_original  \
# 2344                           Гостевой дом Райзен Хаус           Guesthouse
# 3525                               Дом Таунхаус у парка  Cottages_and_Houses
# 1367                 Апартаменты В Зеленоградске у Моря            Apartment
# 4078                          Апартаменты на Лермонтова            Apartment
# 4968                                Guest House Trigona           Guesthouse
# 2770                     Мини-отель Lermontovskiy apart           Mini-hotel
# 2675                             Апартаменты Соммера 12            Apartment
# 2318                         Апартаменты Sommera Center            Apartment
# 1937                Апартаменты в центре Калининграда 1            Apartment
# 1375  Апартаменты Двухкомнатные Рядом с Янтарной Шка...            Apartment
# 4680                               Apartment on Sommera            Apartment
# 4689                                 Natalya Apartments            Apartment
# 2382                   Апартаменты Apartburo Lermontova            Apartment
# 3731   Апартаменты Двухкомнатные на Ленинском проспекте            Apartment
# 3010                               Отель Королева Луиза                Hotel
# 4660              Kvartira V Samom Tsentre Kaliningrada                Hotel
# 3109                          Гостевой дом Baltic Rooms           Guesthouse
# 2445               Апартаменты Квартира Captain's Cabin            Apartment
# 2918                          Апартаменты на Герцена 8А            Apartment
# 4759                      Apartamienty na Giertsiena 8a                Hotel
# 1545                  Апартаменты в центре на Ленинском            Apartment
# 2667       Апартаменты с джакуззи в Историческом Центре            Apartment
# 3440                          Апартаменты Номер у Башни            Apartment
# 3293                           Апартаменты Морской бриз            Apartment
# 4459                   Частный дом у моря Baltic Resort               Resort
# 1531                               Гостевой дом У башни           Guesthouse
# 2374                                           Монетный            Apartment
# 5235                   Апартаменты Квартирное Бюро Гала            Apartment
# 3739  Апартаменты в Историческом Доме в Самом Центре...            Apartment
# 1700                                Бутик-отель ПAPADOX  Boutique_and_Design
# 1906                                   Гостевой Дом Фил           Guesthouse
# 2201                          Апартаменты на Соммера 20            Apartment
# 57                              Апарт-отель Baltapart39                Hotel
# 2266                        Апартаменты Уютная Мансарда            Apartment
# 3673                         Апартаменты на Саратовском            Apartment
# 3631                   Квартира Friendly HomeУютный Дом            Apartment
# 1743    Апартаменты Sunny Svetlogorsk 9 в центре города            Apartment
# 2690    Апартаменты Sunny Svetlogorsk 8 в центре города            Apartment
# 1683                     Апартаменты 2 спальни в центре            Apartment
# 4143               Apartamenty Sunny Svetlogorsk 8,9,10            Apartment
# 1595                      Апартаменты Ольга Светлогорск            Apartment
# 3680   Апартаменты Sunny Svetlogorsk 10 в центре города            Apartment
# 2328                             Апартаменты Кошкин Дом            Apartment
# 3210                             Апартаменты Sea Resort               Resort
# 2551                           Апартаменты Central city            Apartment
# 2048    Апартаменты Немецкая Вилла у Водонапорной Башни            Apartment
# 3541                        Апартаменты в Немецком Доме            Apartment
# 3477            Апартаменты "Из Дома в Дом на Аптечной"            Apartment
# 4741                                Komnaty na Gertsena           Guesthouse
# 1778          Апартаменты Двухкомнатные в центре города            Apartment
# 4473              Жилое помещение на Генерала Соммера 5               Hostel
# 2840                             Апартаменты Happy Home            Apartment
# 4760                            Apart39 on Okruzhnaya 4                Hotel
# 3687                     Апартаменты Солнечные в Центре            Apartment
# 4142                        Apartamenty na Potemkina 17            Apartment
# 3618  Апартаменты Уют и комфорт рядом со всеми досто...            Apartment
# 4751                                     "Elisa Inn" 3*                Hotel
# 3382                                   Апартаменты Маяк            Apartment
# 2153                          Апартаменты Baltic Resort               Resort
# 3082           Апартаменты LovelyHome39 у Нижнего озера            Apartment
#
#               city                                            address  rating  \
# 2344  Зеленоградск              улица Лермонтова, д.9 А, Зеленоградск     9.4
# 3525  Зеленоградск                  улица Лермонтова 2в, Зеленоградск     8.5
# 1367  Зеленоградск              улица Лермонтова, д. 11, Зеленоградск     9.9
# 4078  Зеленоградск              улица Лермонтова, д. 4А, Зеленоградск     0.0
# 4968  Зеленоградск  Ulitsa Lermontova 5a, 238326 Zelenogradsk, Rus...     0.0
# 2770  Зеленоградск               улица Лермонтова, д.4Д, Зеленоградск     9.1
# 2675   Калининград         улица Генерала Соммера, д. 12, Калининград     7.2
# 2318   Калининград          улица Генерала Соммера, д.10, Калининград     9.9
# 1937   Калининград          улица Генерала Соммера, д.10, Калининград     0.0
# 1375   Калининград         улица Генерала Соммера, д. 14, Калининград     9.8
# 4680   Калининград  Generala Sommera Street 16, Kaliningrad, Kalin...     0.0
# 4689   Калининград  ulitsa Sommera, 16, Kaliningrad, Russia, Калин...     0.0
# 2382  Зеленоградск              улица Лермонтова, д. 6А, Зеленоградск     9.6
# 3731   Калининград             Ленинский проспект, д.41А, Калининград     0.0
# 3010  Зеленоградск               улица Московская, д.50, Зеленоградск     8.4
# 4660   Калининград   Leninskij prospekt 41A; Kaliningrad, Калининград     0.0
# 3109   Калининград             Ленинский проспект, д.39А, Калининград     8.0
# 2445   Калининград             Ленинский проспект, д.39А, Калининград     8.2
# 2918  Зеленоградск                  улица Герцена, д.8А, Зеленоградск     8.8
# 4759  Зеленоградск                   8a ulitsa Gertsena, Зеленоградск     0.0
# 1545   Калининград   проспект Ленинский, д. 45А (кв. 11), Калининград     9.8
# 2667  Зеленоградск              улица Потемкина, д. 13а, Зеленоградск     8.2
# 3440  Зеленоградск       2-й Саратовский переулок, д. 8, Зеленоградск     7.7
# 3293  Зеленоградск               улица Потемкина, д.13А, Зеленоградск     9.3
# 4459  Зеленоградск            переулок Саратовский, д.1, Зеленоградск     0.0
# 1531  Зеленоградск        2-й Саратовский переулок, д.5, Зеленоградск     8.9
# 2374   Калининград              ул. Генерала Соммера, 13, Калининград     9.2
# 5235   Калининград          улица Генерала Соммера, д.13, Калининград     9.9
# 3739   Калининград  улица Подполковника Иванникова, д.2-4, Калинин...     0.0
# 1700  Зеленоградск             улица Саратовская, д. 2а, Зеленоградск     9.2
# 1906  Зеленоградск              улица Саратовская, д.4б, Зеленоградск     9.6
# 2201   Калининград      улица Генерала Соммера, д. 20-19, Калининград     9.1
# 57    Зеленоградск                   улица Герцена, д.5, Зеленоградск     9.0
# 2266  Зеленоградск              переулок Потемкина, д.7, Зеленоградск     6.2
# 3673  Зеленоградск       2-й Саратовский переулок, д. 3, Зеленоградск     6.2
# 3631  Зеленоградск               улица Потемкина, д. 16, Зеленоградск     0.0
# 1743   Светлогорск                   улица Аптечная, д.6, Светлогорск     9.8
# 2690   Светлогорск                   улица Аптечная, д.6, Светлогорск     9.5
# 1683   Калининград             улица генерала Соммера 36, Калининград     9.4
# 4143   Светлогорск  Kaliningradskaja oblast', g. Svetlogorsk, ul. ...     0.0
# 1595   Светлогорск                   улица Аптечная, д.6, Светлогорск     9.8
# 3680   Светлогорск                   улица Аптечная, д.6, Светлогорск     6.0
# 2328  Зеленоградск                улица Ткаченко, д. 25, Зеленоградск     9.2
# 3210   Светлогорск                   улица Аптечная, д.8, Светлогорск     0.0
# 2551   Калининград              Ленинский проспект, д.37, Калининград     7.9
# 2048  Зеленоградск                  улица Герцена, д. 7, Зеленоградск    10.0
# 3541  Зеленоградск                  улица Герцена, д. 7, Зеленоградск     9.7
# 3477   Светлогорск                  улица Аптечная, д. 6, Светлогорск     9.9
# 4741  Зеленоградск  ul. Gertsena 21 A, 238530 Zelenogradsk, Russia...     0.0
# 1778   Калининград          улица Генерала Соммера, д.34, Калининград    10.0
# 4473   Калининград           улица Генерала Соммера, д.5, Калининград     0.0
# 2840  Зеленоградск                 Окружная улица, д.2А, Зеленоградск    10.0
# 4760  Зеленоградск                  Ulitsa Okruzhnaya 4, Зеленоградск     0.0
# 3687   Калининград          улица Генерала Соммера, д.44, Калининград     0.0
# 4142  Зеленоградск  Zelenogradsk,ul. Potemkina 17, kv. 191, Зелено...     0.0
# 3618   Калининград          улица Генерала Соммера, д.26, Калининград     0.0
# 4751  Зеленоградск  g. Zelenogradsk, ul. Tkachenko, d. 4., Зеленог...     0.0
# 3382  Зеленоградск                    улица Ткаченко, 1, Зеленоградск     7.5
# 2153  Зеленоградск                  улица Ткаченко, д.1, Зеленоградск     9.4
# 3082   Калининград          улица Генерала Соммера, д.50, Калининград     0.0
#
#       rating_5  review_count  region  ...  email  phone website       uid  \
# 2344      4.70           0.0       2  ...    NaN    NaN     NaN   8854429
# 3525      4.25           0.0       2  ...    NaN    NaN     NaN   9996779
# 1367      4.95           0.0       2  ...    NaN    NaN     NaN  10019454
# 4078      0.00           0.0       2  ...    NaN    NaN     NaN  10480551
# 4968      0.00           3.0       2  ...    NaN    NaN     NaN   6719101
# 2770      4.55           0.0       2  ...    NaN    NaN     NaN  10467382
# 2675      3.60           0.0       2  ...    NaN    NaN     NaN  10016145
# 2318      4.95           0.0       2  ...    NaN    NaN     NaN  10210905
# 1937      0.00           0.0       2  ...    NaN    NaN     NaN  10618164
# 1375      4.90           0.0       2  ...    NaN    NaN     NaN  10459031
# 4680      0.00           0.0       2  ...    NaN    NaN     NaN   8359459
# 4689      0.00           0.0       2  ...    NaN    NaN     NaN   8685256
# 2382      4.80           0.0       2  ...    NaN    NaN     NaN   9999359
# 3731      0.00           0.0       2  ...    NaN    NaN     NaN  10630600
# 3010      4.20           0.0       2  ...    NaN    NaN     NaN   8023676
# 4660      0.00           0.0       2  ...    NaN    NaN     NaN  10063612
# 3109      4.00           0.0       2  ...    NaN    NaN     NaN  10002159
# 2445      4.10           0.0       2  ...    NaN    NaN     NaN  10488730
# 2918      4.40           0.0       2  ...    NaN    NaN     NaN  10011393
# 4759      0.00           0.0       2  ...    NaN    NaN     NaN   9304431
# 1545      4.90           0.0       2  ...    NaN    NaN     NaN   9999555
# 2667      4.10           0.0       2  ...    NaN    NaN     NaN   9932510
# 3440      3.85           0.0       2  ...    NaN    NaN     NaN  10442693
# 3293      4.65           0.0       2  ...    NaN    NaN     NaN   9996111
# 4459      0.00           0.0       2  ...    NaN    NaN     NaN  10437940
# 1531      4.45           0.0       2  ...    NaN    NaN     NaN   6503105
# 2374      4.60           0.0       2  ...    NaN    NaN     NaN  10453341
# 5235      4.95           0.0       2  ...    NaN    NaN     NaN  10330936
# 3739      0.00           0.0       2  ...    NaN    NaN     NaN  10618162
# 1700      4.60         199.0       2  ...    NaN    NaN     NaN   8550052
# 1906      4.80           0.0       2  ...    NaN    NaN     NaN  10159617
# 2201      4.55           0.0       2  ...    NaN    NaN     NaN  10011273
# 57        4.50           0.0       2  ...    NaN    NaN     NaN  10041203
# 2266      3.10           0.0       2  ...    NaN    NaN     NaN  10135076
# 3673      3.10           0.0       2  ...    NaN    NaN     NaN  10013835
# 3631      0.00           0.0       2  ...    NaN    NaN     NaN  10682249
# 1743      4.90           0.0       2  ...    NaN    NaN     NaN  10003089
# 2690      4.75           0.0       2  ...    NaN    NaN     NaN  10003107
# 1683      4.70           0.0       2  ...    NaN    NaN     NaN   9999786
# 4143      0.00           0.0       2  ...    NaN    NaN     NaN  10329569
# 1595      4.90           0.0       2  ...    NaN    NaN     NaN  10012000
# 3680      3.00           0.0       2  ...    NaN    NaN     NaN  10003102
# 2328      4.60           0.0       2  ...    NaN    NaN     NaN  10669055
# 3210      0.00           0.0       2  ...    NaN    NaN     NaN  10135920
# 2551      3.95           0.0       2  ...    NaN    NaN     NaN  10159893
# 2048      5.00           0.0       2  ...    NaN    NaN     NaN  10373301
# 3541      4.85           0.0       2  ...    NaN    NaN     NaN  10373311
# 3477      4.95           0.0       2  ...    NaN    NaN     NaN  10373260
# 4741      0.00           3.0       2  ...    NaN    NaN     NaN   8401698
# 1778      5.00           0.0       2  ...    NaN    NaN     NaN  10488731
# 4473      0.00           0.0       2  ...    NaN    NaN     NaN  10626069
# 2840      5.00           0.0       2  ...    NaN    NaN     NaN  10622386
# 4760      0.00           0.0       2  ...    NaN    NaN     NaN   9295458
# 3687      0.00           0.0       2  ...    NaN    NaN     NaN  10211832
# 4142      0.00           0.0       2  ...    NaN    NaN     NaN  10592291
# 3618      0.00           0.0       2  ...    NaN    NaN     NaN  10612204
# 4751      0.00           0.0       2  ...    NaN    NaN     NaN  10009761
# 3382      3.75           0.0       2  ...    NaN    NaN     NaN  10000478
# 2153      4.70           0.0       2  ...    NaN    NaN     NaN  10362700
# 3082      0.00           0.0       2  ...    NaN    NaN     NaN  10661851
#
#                     parsing_time        lat        lon  len_phone  \
# 2344  2023-09-26 20:56:02.013106  54.959260  20.489283        NaN
# 3525  2023-09-26 20:56:02.013106  54.960530  20.489376        NaN
# 1367  2023-09-26 20:56:02.013106  54.960102  20.489466        NaN
# 4078  2023-09-26 20:56:02.013106  54.960358  20.489641        NaN
# 4968  2023-09-26 20:56:02.013106  54.959423  20.489948        NaN
# 2770  2023-09-26 20:56:02.013106  54.960175  20.489988        NaN
# 2675  2023-09-26 20:56:02.013106  54.715775  20.506355        NaN
# 2318  2023-09-26 20:56:02.013106  54.715630  20.505842        NaN
# 1937  2023-09-26 20:56:02.013106  54.715630  20.505842        NaN
# 1375  2023-09-26 20:56:02.013106  54.715800  20.506527        NaN
# 4680  2023-09-26 20:56:02.013106  54.715866  20.506765        NaN
# 4689  2023-09-26 20:56:02.013106  54.715820  20.506859        NaN
# 2382  2023-09-26 20:56:02.013106  54.959908  20.490492        NaN
# 3731  2023-09-26 20:56:02.013106  54.715090  20.505987        NaN
# 3010  2023-09-26 20:56:02.013106  54.961407  20.488760        NaN
# 4660  2023-09-26 20:56:02.013106  54.715137  20.505943        NaN
# 3109  2023-09-26 20:56:02.013106  54.715202  20.505825        NaN
# 2445  2023-09-26 20:56:02.013106  54.715202  20.505825        NaN
# 2918  2023-09-26 20:56:02.013106  54.958770  20.482729        NaN
# 4759  2023-09-26 20:56:02.013106  54.958843  20.482702        NaN
# 1545  2023-09-26 20:56:02.013106  54.714886  20.506292        NaN
# 2667  2023-09-26 20:56:02.013106  54.958073  20.483646        NaN
# 3440  2023-09-26 20:56:02.013106  54.958538  20.483664        NaN
# 3293  2023-09-26 20:56:02.013106  54.958073  20.483646        NaN
# 4459  2023-09-26 20:56:02.013106  54.959496  20.483107        NaN
# 1531  2023-09-26 20:56:02.013106  54.958817  20.483080        NaN
# 2374  2023-09-26 20:56:02.013106  54.716404  20.506428        NaN
# 5235  2023-09-26 20:56:02.013106  54.716404  20.506428        NaN
# 3739  2023-09-26 20:56:02.013106  54.716682  20.505950        NaN
# 1700  2023-09-26 20:56:02.013106  54.959810  20.482452        NaN
# 1906  2023-09-26 20:56:02.013106  54.959700  20.484688        NaN
# 2201  2023-09-26 20:56:02.013106  54.715870  20.507345        NaN
# 57    2023-09-26 20:56:02.013106  54.959583  20.482029        NaN
# 2266  2023-09-26 20:56:02.013106  54.958540  20.484463        NaN
# 3673  2023-09-26 20:56:02.013106  54.959236  20.483126        NaN
# 3631  2023-09-26 20:56:02.013106  54.957970  20.484858        NaN
# 1743  2023-09-26 20:56:02.013106  54.941660  20.152510        NaN
# 2690  2023-09-26 20:56:02.013106  54.941660  20.152510        NaN
# 1683  2023-09-26 20:56:02.013106  54.715980  20.510918        NaN
# 4143  2023-09-26 20:56:02.013106  54.941700  20.152500        NaN
# 1595  2023-09-26 20:56:02.013106  54.941660  20.152510        NaN
# 3680  2023-09-26 20:56:02.013106  54.941660  20.152510        NaN
# 2328  2023-09-26 20:56:02.013106  54.959732  20.481695        NaN
# 3210  2023-09-26 20:56:02.013106  54.941950  20.152985        NaN
# 2551  2023-09-26 20:56:02.013106  54.714874  20.505060        NaN
# 2048  2023-09-26 20:56:02.013106  54.959427  20.482162        NaN
# 3541  2023-09-26 20:56:02.013106  54.959427  20.482162        NaN
# 3477  2023-09-26 20:56:02.013106  54.941803  20.152277        NaN
# 4741  2023-09-26 20:56:02.013106  54.957275  20.482540        NaN
# 1778  2023-09-26 20:56:02.013106  54.716152  20.510864        NaN
# 4473  2023-09-26 20:56:02.013106  54.715730  20.504784        NaN
# 2840  2023-09-26 20:56:02.013106  54.958496  20.488370        NaN
# 4760  2023-09-26 20:56:02.013106  54.958380  20.489630        NaN
# 3687  2023-09-26 20:56:02.013106  54.715508  20.511053        NaN
# 4142  2023-09-26 20:56:02.013106  54.957100  20.483100        NaN
# 3618  2023-09-26 20:56:02.013106  54.716045  20.509275        NaN
# 4751  2023-09-26 20:56:02.013106  54.959500  20.477800        NaN
# 3382  2023-09-26 20:56:02.013106  54.958866  20.477816        NaN
# 2153  2023-09-26 20:56:02.013106  54.958866  20.477816        NaN
# 3082  2023-09-26 20:56:02.013106  54.716080  20.511583        NaN
#
#                         test  count_gost
# 2344   [54.95926, 20.489283]         279
# 3525   [54.96053, 20.489376]         277
# 1367  [54.960102, 20.489466]         276
# 4078  [54.960358, 20.489641]         276
# 4968  [54.959423, 20.489948]         270
# 2770  [54.960175, 20.489988]         269
# 2675  [54.715775, 20.506355]         262
# 2318   [54.71563, 20.505842]         262
# 1937   [54.71563, 20.505842]         262
# 1375    [54.7158, 20.506527]         261
# 4680  [54.715866, 20.506765]         259
# 4689   [54.71582, 20.506859]         258
# 2382  [54.959908, 20.490492]         255
# 3731   [54.71509, 20.505987]         254
# 3010   [54.961407, 20.48876]         254
# 4660  [54.715137, 20.505943]         253
# 3109  [54.715202, 20.505825]         253
# 2445  [54.715202, 20.505825]         253
# 2918   [54.95877, 20.482729]         253
# 4759  [54.958843, 20.482702]         252
# 1545  [54.714886, 20.506292]         252
# 2667  [54.958073, 20.483646]         251
# 3440  [54.958538, 20.483664]         251
# 3293  [54.958073, 20.483646]         251
# 4459  [54.959496, 20.483107]         248
# 1531   [54.958817, 20.48308]         248
# 2374  [54.716404, 20.506428]         247
# 5235  [54.716404, 20.506428]         247
# 3739   [54.716682, 20.50595]         246
# 1700   [54.95981, 20.482452]         246
# 1906    [54.9597, 20.484688]         245
# 2201   [54.71587, 20.507345]         245
# 57    [54.959583, 20.482029]         245
# 2266   [54.95854, 20.484463]         243
# 3673  [54.959236, 20.483126]         242
# 3631   [54.95797, 20.484858]         242
# 1743    [54.94166, 20.15251]         241
# 2690    [54.94166, 20.15251]         241
# 1683   [54.71598, 20.510918]         241
# 4143      [54.9417, 20.1525]         241
# 1595    [54.94166, 20.15251]         241
# 3680    [54.94166, 20.15251]         241
# 2328  [54.959732, 20.481695]         240
# 3210   [54.94195, 20.152985]         240
# 2551   [54.714874, 20.50506]         239
# 2048  [54.959427, 20.482162]         238
# 3541  [54.959427, 20.482162]         238
# 3477  [54.941803, 20.152277]         238
# 4741   [54.957275, 20.48254]         238
# 1778  [54.716152, 20.510864]         238
# 4473   [54.71573, 20.504784]         236
# 2840   [54.958496, 20.48837]         236
# 4760    [54.95838, 20.48963]         236
# 3687  [54.715508, 20.511053]         234
# 4142      [54.9571, 20.4831]         234
# 3618  [54.716045, 20.509275]         233
# 4751      [54.9595, 20.4778]         232
# 3382  [54.958866, 20.477816]         232
# 2153  [54.958866, 20.477816]         232
# 3082   [54.71608, 20.511583]         232
#
# [60 rows x 24 columns]

# %%
df.count_gost.hist()
# Out:
# <Axes: >

# %%
df.sort_values('count_gost', ascending=False).head(2)
# Out:
#          id                 create_time                     title  \
# 2344  82873  2023-09-26 14:49:26.201114  Гостевой дом Райзен Хаус
# 3525  84132  2023-09-26 14:54:00.667660      Дом Таунхаус у парка
#
#       hotel_type_original          city  \
# 2344           Guesthouse  Зеленоградск
# 3525  Cottages_and_Houses  Зеленоградск
#
#                                     address  rating  rating_5  review_count  \
# 2344  улица Лермонтова, д.9 А, Зеленоградск     9.4      4.70           0.0
# 3525      улица Лермонтова 2в, Зеленоградск     8.5      4.25           0.0
#
#       region  ...  email  phone website      uid                parsing_time  \
# 2344       2  ...    NaN    NaN     NaN  8854429  2023-09-26 20:56:02.013106
# 3525       2  ...    NaN    NaN     NaN  9996779  2023-09-26 20:56:02.013106
#
#            lat        lon  len_phone                   test  count_gost
# 2344  54.95926  20.489283        NaN  [54.95926, 20.489283]         279
# 3525  54.96053  20.489376        NaN  [54.96053, 20.489376]         277
#
# [2 rows x 24 columns]

# %% [markdown]
# координаты центра пересечения диагоналей квадрата с наибольшей плотностью гостиниц: lat: 54.95926, lon: 20.489283

# %% [markdown]
# # Задачи со *

# %%
df2_title = df2.title.unique()
df2_title
# Out:
# array(['By Richotels, хостел', 'Звездный дом в Абзаково',
#        'Zoofa, гостиница', 'Золотая юрта', 'Сарыташ, база отдыха', 'Рина',
#        'Жемчужина, гостиница', 'Березка, туристическая база',
#        'Забота, турбаза', 'Юрматы, гостиница', 'Йола, глэмпинг',
#        'Яратау, гостиница', 'Вояж, гостиница',
#        'Гранд-Отель Восток, гостиница', 'ВолнаСити, отель',
#        'Vgosti, гостиница', 'Вершина, гостиница', 'Веранда, гостевой дом',
#        'Уязы-Тау, гостиница', 'Табын, турбаза', 'Юность',
#        'У капитана Флинта', 'Версаль, гостиничный комплекс',
#        'Лель, отель', 'Цветы, банная усадьба', 'Малиновка, турбаза',
#        'Медвежий угол-Иремель, база отдыха', 'Меркурий, гостиница',
#        'Нарыстау, туристическая база', 'Тихий берег',
#        'ОДК-УМПО, гостиница', 'Тау-Таш, гостиница', 'Тау-Таш, ресторан',
#        'Тан, гостиничный комплекс', 'Судовая гора, гостевой дом',
#        'СТОКГОЛЬМ, мини-отель', 'Соловушка, база отдыха',
#        'Вояж, гостевой дом', 'Smart hotel kdo Уфа',
#        'Sheratonplaza Ufa Congress Hotel, гостиница',
#        'Шатлык, гостевой дом', 'Гостиница', 'База отдыха',
#        'Альпийский, гостиничный комплекс',
#        'Жар-батюшка, гостинично-банный комплекс', 'San Marco, гостиница',
#        'Радуга, гостиница', 'Ашкадар, гостиница', 'Радость, отель-хостел',
#        '7 озер, гостиничный комплекс', 'Башкирия, гостиничный комплекс',
#        'Удача, база отдыха', 'Лесная усадьба, эко-комплекс',
#        'БашУлей, база отдыха', 'Гнездо, экоусадьба',
#        'Ай да вкус, гостиничный комплекс', 'Комфорт, комплекс',
#        'Лесное озеро, база отдыха', 'Рязановский пруд, база отдыха',
#        'Pro отдых, глэмпинг', 'Президент отель, гостиничный комплекс',
#        'Pastel, гостиница', 'Причал, гостиница',
#        'Нотера, гостиничный комплекс', 'Ясная поляна, отель',
#        'Отдых, отель', 'Островок, база отдыха',
#        'Бобер, охотничье хозяйство', 'Нурлы, комплекс',
#        'Малина, база отдыха', 'Азур, гостевой дом',
#        'Nesterov Plaza, отель', 'Место силы-пирамида, усадьба',
#        'Надежда, гостиница', 'Мраткино.ру, гостиница',
#        'На высоте, гостиница', 'Мед от пчел', 'Малинkи', 'Liberti, отель',
#        'Лагуна, гостиница', 'La Bereg, гостевой комплекс',
#        'Культамак, туристская база', 'Кук-Караук, база отдыха',
#        'Ковчег, база отдыха', 'Kedr camp, глэмпинг', 'Капова-тур',
#        'Тёплое озеро, база отдыха', 'Аракуль, гостиница',
#        'Ной, гостиница', 'Искушта хаятт',
#        'ИремельОтель, гостиничный комплекс',
#        'Империя, оздоровительно-банный комплекс',
#        'Ильмурзино, парк семейного отдыха', 'Эдем', 'Эгоист, глэмпинг',
#        'Villa Blanca', 'Яш-тан, отель', 'Чемодан, гостиница',
#        'Альфа, гостиничный комплекс', 'Татьяна, гостиница',
#        'Астория, гостиница', 'Апартаменты', 'Шале Basel, отель',
#        'Юг, гостиница', 'Посадская, гостиничный комплекс',
#        'Кама, гостиница', 'БуРай, гостиница', 'Эко-стиль, отель',
#        'Main room, хостел', 'Евразия, гостиница', 'Британия, хостел',
#        '100 друзей, хостел', 'Хижина Шамана, база отдыха',
#        'Hilton Garden Inn Ufa Riverside, отель',
#        'Hampton by hilton Ufa, отель', 'Pandora, гостиница',
#        'Зеленая роща, гостиница', 'Абсолют, отель', '7Days',
#        'Красный ключ, гостевой дом', 'Купеческая', 'Емеля, гостиница',
#        'Алтынай, гостиница', 'Гости',
#        'Горный воздух, детский оздоровительный лагерь',
#        'Любимое место, база отдыха', 'Южный, гостиничный комплекс',
#        'Уральский региональный экспериментальный учебно-научный комплекс',
#        'Емеля24, гостиница', 'Дом на Банном', 'Ель, гостевой дом',
#        'DEVONHOTEL, гостинично-ресторанный комплекс',
#        'Дежавю, гостевой дом', 'Белый город, гостевой дом',
#        'Берлога, база отдыха', 'Людмила, гостевой дом',
#        'Смайл, мини-гостиница', 'Сова, гостевой дом',
#        'Олимп, апарт-отель', 'Бижбуляк, гостиница',
#        '33 медведя, клуб отдыха', 'Акият, отель', 'Ак керман, гостиница',
#        'У Ильича, сауна', 'Аджио, гостиница',
#        'Свояк, гостиничный комплекс', 'Жемчужина',
#        'Звездный, клуб активного отдыха', 'Юлсы, гостиница',
#        'Гостевой дом', 'Глэмпинг', 'Семейные истории, база отдыха',
#        'Родной, глэмпинг', 'Дом отдыха',
#        'Берлога на озере Калкан, база отдыха', 'Тратау',
#        'Ивкор, база отдыха', 'Вечер, гостиница',
#        'Агидельтрансавто, гостиница',
#        'Караидель, физкультурно-оздоровительный комплекс',
#        'Версаль, гостиница', 'Панорама, мини-отель',
#        'Маяк, гостиничный комплекс', 'Favorit, гостиница',
#        'Любизар, гостиница', 'Три пескаря', 'Путник, гостевой дом',
#        'Банная Усадьба, оздоровительный комплекс', 'Чишмы М-5, гостиница',
#        'Черемушки', 'Green Park Чайка', 'Касабланка, база отдыха',
#        'Бурзян, туристическая база', 'Автобус в лесу',
#        'Место силы, бунгало-клуб', 'Bora Bora, база отдыха',
#        'Легенда, база отдыха', 'Солнечная, база отдыха',
#        'Лесная сказка, база отдыха', 'Black River', 'Как дома',
#        'Биатлон, гостиница', 'Березка', 'Косая степь, база отдыха',
#        'Озёрная', 'Акбаш, база отдыха', 'Башкирская деревня, база отдыха',
#        'Барский Дворик, гостевой дом', 'Грин, отель',
#        'Урал тау, гостиничный комплекс', 'Аристоль, отель',
#        'А-бунгало на банном', 'Arderia, гостевые комнаты',
#        'Анна, гостиница', 'Амакс Сити-отель, гостиница',
#        'Амакс Сити-отель, прачечная',
#        'Aldego hotel&SPA, гостиничный комплекс', 'Акбузат, база отдыха',
#        'Еловое, гостиница', 'Абзаково, курортный комплекс',
#        'Эдельвейс, отель', 'Абсолют, гостиница',
#        'У трех медведей, частный пансионат отдыха',
#        'Pastel Lux, мини-отель', 'На белой, база отдыха',
#        'Grand шале, д. Зеленая Поляна', 'Каменный цветок, гостевой дом',
#        'Дарина, отель', 'Акназар, база отдыха', 'Шале поляна, отель',
#        'Green home, гостевой дом', 'Уютель, мини-отель',
#        'Chalet Briole, гостиничный комплекс', 'Квартиры-Уфа', 'Новосел',
#        'Межгорье, мини-гостиница', 'Сильвер, отель', 'Домашний, отель',
#        'Marichalet, отель', 'Апарт-отель', 'Серебряный рожок, гостиница',
#        'Молодость, студия', 'Гранд, отель', 'М7, мотель',
#        'Пушкин, бутик-отель', 'Тихорецкий, гостевой дом',
#        'Автомобилист, гостиница', 'Дубрава, база отдыха', 'Мини-отель',
#        'Автодвор, гостиница', 'Созвездие стрельца, гостевой дом',
#        'Общепит, мотель', 'Гостевой дом Башкирия, гостевой дом',
#        'Ural Taur, гостиничный комплекс', 'Маракеш, гостиница',
#        'Уршак, гостиница', 'СЕМЬЯ, мини-гостиница', 'Корона, отель',
#        'В центре+, отель', 'Павловский парк, гостиница',
#        'Таганай, апартаментный комплекс', 'Alpen hof, отель',
#        'Бунгало club, гостиница', 'Гостиный двор, гостиница',
#        'Дом у озера, гостиница', 'Family, отель',
#        'Медведь, гостиничный комплекс', 'Маяк, гостиница',
#        '1000 историй, турбаза', 'Баня', 'Рябиновая, гостиница',
#        'Корона, гостиница', 'Урал Халяль', 'Молодость', 'Винсент, отель',
#        'Усолка, база отдыха', 'Баба Яга, отель', 'Павловка, гостиница',
#        'Аслы-house, база отдыха', 'Гранд, гостиница', 'Мотель',
#        'Уют, гостиница', 'Berloga hostel', 'Узма, мини-отель',
#        'Алкино, мини-отель', 'Восток1453, мотель',
#        'Восток1453, гостиница', 'Key, апарт-отель',
#        'На луговой, гостиница', 'Общежитие №18',
#        'Европа House, гостевой дом', 'Влада by richotels',
#        'Авиатор, гостиница', 'Семейный, отель', 'Добрый день, гостиница',
#        'Палитра by richotels', 'Азалия, гостиница', 'Эгида, гостиница',
#        'Мини-гостиница', 'Куба, гостиница', 'Мирас, гостиница',
#        'Сказка, мини-отель', 'У Ашота, гостиница', 'Apart_ufa, гостиница',
#        'Транзит, гостиница', 'Молодежная, гостиница', 'Бирск, гостиница',
#        'Алиса, гостиничный комплекс', 'Урал, гостиница',
#        'Солнечный, мотель', 'Малый отель на Черниковской',
#        'Клеопатра, гостиница', 'Уфа-Астория, гостиница',
#        'Айгуль, гостиница', 'Успех, гостиница', 'Комфорт, гостиница',
#        'Алга, гостиница', 'Багира, гостиничный комплекс',
#        'Солнечный, гостиничный комплекс',
#        'Урал, гостинично-оздоровительный комплекс',
#        'Ольховка, санаторий-профилакторий', 'Елена, гостиничный комплекс',
#        'Польский городок, гостиница', 'Парк Зилим, база отдыха',
#        'Орленок, апарт-отель', 'Мир, гостевой дом', 'Goldy Land',
#        'Перчик, гостиница', 'Yuremis-Camp, база отдыха', 'Халва',
#        'Уютный', 'Воздух, глэмпинг', 'Инзер, гостиница',
#        'Даниловский парк, база отдыха', 'Barhat, гостиница',
#        'Салават, гостиничный комплекс', 'Уфа, отель',
#        'Красивая поляна, мотель', 'Астра, гостиница', 'Севан, гостиница',
#        'Новоженовский, отель', 'Прометей, гостиница',
#        'Якташлар, комплекс', 'Вечный зов', 'Звездный, отель',
#        'Ковчег, гостиничный комплекс', 'Лесная Сказка, дом отдыха',
#        'Делюкс, гостиница', 'Озон тау', 'Нурлы Имам, гостиница',
#        'Роза ветров, гостиничный комплекс', 'Монтажник',
#        'Савой, гостиница', 'Ямашла, база отдыха', 'Омшаник, база отдыха',
#        'Уралдом, гостиница', 'Юлбарс, гостиница', 'Bankir, отель',
#        'Мегаполис, гостиница', 'Регион 102, гостиница',
#        'Регион 02, гостиница', 'Пальма, мотель', 'Отдых, гостиница',
#        'Престиж, гостиница', 'Тихий утес, гостевой дом',
#        'Суперчик, гостиница', 'на Мраткино, мини-отель',
#        'Москвич, гостиница', 'Шайтан-Кудей, геопарк', 'Кыйгыр',
#        'Лена, база отдыха', 'Lounge villa, база отдыха',
#        'Дальнобойщик, гостиница', 'Нарыстау, гостиница',
#        'Ардан, база отдыха', 'Три медведя', 'Кунакхана, гостиница',
#        'Макс, гостиница', 'Элита, база отдыха', 'Гостиничный комплекс',
#        'Урман, база отдыха', 'Кураж, гостиница', 'Дуслык, гостиница',
#        'Vgosti, мини-отель', 'Утэп, гостиница', 'Азимут, гостиница',
#        'Якташ, гостиница', 'Автосити, придорожный комплекс',
#        'Ласточка, гостиница', 'Аристократ, гостиничный комплекс',
#        'Добр здравич, гостиница', 'Предгорье, гостиница',
#        'Курай, гостиница', 'Восточная, гостиница', 'Империал, гостиница',
#        'Звезда Урала, гостиница', 'Столица, мини-гостиница',
#        'Перекрёсток, гостиница', 'Смак, гостиница',
#        'Зирганский элеватор, гостиница',
#        'Восточный, гостиничный комплекс', 'Forest House', 'Уют',
#        'Виктория, гостиница', 'Линкин park', 'Ологужан, база отдыха',
#        'Орлиное гнездо, гостевой дом', 'Месягутово, гостиница',
#        'Миляш, гостиница', 'Сосновый бор, гостиница', 'Огонек, гостиница',
#        'Дельта, гостиница', 'Горный воздух, гостевой дом',
#        'На Березовой, апарт-отель', 'В гостях у дворика, гостиница',
#        'Альпин Шале, гостевой дом', 'Арслан, отель',
#        'Вертикаль, гостиничный комплекс', 'На Кирова, гостиница',
#        'Ургун, гостиница', 'AZIMUT Сити Отель Уфа', 'Нур, хостел',
#        'Панорама, гостиница', 'Сухов ключ, турбаза',
#        'Высота 806, мини-отель', 'Арджуна, гостевой дом',
#        'Три студии, мини-отель', 'Кубагушево вилладж, база отдыха',
#        'Марьино, база отдыха', 'Sunrise eco hotel, отель',
#        'Лыжа, гостевой дом', 'Банный хутор', 'Polyanka, отель',
#        'Заря, гостиница', 'Тенгри, база отдыха', 'Белорецк, гостиница',
#        'Усадьба, гостиница', 'Яшма, гостиница', 'Иремель, гостиница',
#        'Миякинский дворик, гостиница', 'Дюртюли, гостиница',
#        'Белебей, гостиница', 'Ямашла, гостиница', 'Оскар, отель',
#        'Аврора, гостиница', 'Инфинити, банно-гостиничный комплекс',
#        'Башкортостан, гостиничный комплекс', 'Давлеканово, гостиница',
#        'Йондоз, гостиница', 'Vinograd, гостиница',
#        'Октябрьская, гостиница', 'Express, отель',
#        'Кармаскалы, гостиница', 'Агидель, гостиница',
#        'Александрия, гостиница', 'Алая Роза, гостиница',
#        'Кумертау, гостиница', 'Кызыл Яр', 'Бикбау, гостиница',
#        'Золотое кольцо, гостиница', 'Башкирия, гостиница',
#        'Центральная, гостиница', 'Толбазы, гостиница',
#        'Караидель, гостиница', 'Александровский, придорожный комплекс',
#        'Terra, загородный СПА-отель',
#        'Малина, банно-гостиничный комплекс', 'Техсервис, гостиница',
#        'Аэропорт aeropot hotel, гостиница',
#        'Белая река, придорожный комплекс', 'Горки, актив-отель',
#        'Автоотдых, кафе-гостиница', 'Асылы-Куль', 'Лилия',
#        'Актау, гостиница', 'Райса, гостиница', 'Бриз, гостиница', 'Визит',
#        'Беркут, гостиница', 'Замок, гостиница',
#        'Гостиница квартирного типа', 'FlussHaus, гостиница',
#        'День-ночь, гостиница', 'Илиш, гостиница', 'Кургазак, гостиница',
#        'Байтуган, гостиница', 'Урман, гостиница',
#        'На Невского, гостиница', 'Терраса, гостиница', 'Гостинница',
#        'Триумф', 'Крепость, гостиница', 'Агидель, турбаза',
#        'Nugush_camping', 'Родник, гостиница', 'Самрау, гостиница',
#        'Белоречье, гостиница', '007, отель', 'Country hope, мини-отель',
#        'Культамак, туристическая база', 'Гостиница Ашкадар',
#        'Бабай, гостиница', 'Березка, гостиница'], dtype=object)

# %%
df1_unique_title = df1[~(df1['title'].isin(df2_title))]
df1_unique_title
# Out:
#          id                 create_time                             title  \
# 0     81842  2023-09-26 14:45:42.910962  Апартаменты Baltia Западный Пляж
# 1     86341  2023-09-26 15:01:55.184815                     Отель Авиатор
# 2     86420  2023-09-26 15:02:12.005085                         Клеопатра
# 3     86421  2023-09-26 15:02:12.225334                           Татьяна
# 4     85898  2023-09-26 15:00:19.217359                Мини-Отель Чемодан
# ...     ...                         ...                               ...
# 5253  86744  2023-09-26 15:03:21.089955                   Podushka Hostel
# 5254  86790  2023-09-26 15:03:30.721937                Lux apartament UFA
# 5255  87120  2023-09-26 15:04:39.726907                           Биатлон
# 5256  87165  2023-09-26 15:04:49.051042                              Лидо
# 5257  87190  2023-09-26 15:04:54.242964                 Airport Hotel Ufa
#
#      hotel_type_original          city  \
# 0              Apartment  Зеленоградск
# 1                  Hotel           Уфа
# 2                  Hotel           Уфа
# 3                  Hotel         Сибай
# 4             Mini-hotel   Стерлитамак
# ...                  ...           ...
# 5253              Hostel           Уфа
# 5254           Apartment           Уфа
# 5255               Hotel           Уфа
# 5256               Hotel           Уфа
# 5257               Hotel           Уфа
#
#                                                 address  rating  rating_5  \
# 0                 улица Приморская, д. 31, Зеленоградск    10.0      5.00
# 1                            улица Мушникова, д.28, Уфа     8.7      4.35
# 2                      Коммунистическая ул., д. 53, Уфа     6.3      3.15
# 3                           Учалинская улица, 37, Сибай    10.0      5.00
# 4                     улица Дружбы, д.28 Д, Стерлитамак     8.0      4.00
# ...                                                 ...     ...       ...
# 5253  Ulitsa Lenina, 9/11, 3, flat 24, Ufa, Russia, Уфа     7.5      3.75
# 5254     Ulitsa Mingazheva 102, 450078 Ufa, Russia, Уфа     0.0      0.00
# 5255                                ул. Комарова 1, Уфа     0.0      0.00
# 5256                      ул. Менделеева, д. 160/3, Уфа     0.0      0.00
# 5257        Poselok Bulgakova, Mikroraion Aeroport, Уфа     0.0      0.00
#
#       review_count  region  ...  rooms_count  contact_social  description  \
# 0                0       2  ...          NaN             NaN          NaN
# 1                5       2  ...          8.0             NaN          NaN
# 2               10       2  ...         15.0             NaN          NaN
# 3                2       2  ...         15.0             NaN          NaN
# 4                0       2  ...         23.0             NaN          NaN
# ...            ...     ...  ...          ...             ...          ...
# 5253             0       2  ...          NaN             NaN          NaN
# 5254             0       2  ...          1.0             NaN          NaN
# 5255             0       2  ...          NaN             NaN          NaN
# 5256            21       2  ...         18.0             NaN          NaN
# 5257             0       2  ...        123.0             NaN          NaN
#
#       email  phone  website       uid                parsing_time        lat  \
# 0       NaN    NaN      NaN  10595357  2023-09-26 20:56:02.013106  54.951103
# 1       NaN    NaN      NaN   8332081  2023-09-26 20:56:02.013106  54.783913
# 2       NaN    NaN      NaN   7724907  2023-09-26 20:56:02.013106  54.726463
# 3       NaN    NaN      NaN   6598197  2023-09-26 20:56:02.013106  52.719230
# 4       NaN    NaN      NaN   8622634  2023-09-26 20:56:02.013106  53.642567
# ...     ...    ...      ...       ...                         ...        ...
# 5253    NaN    NaN      NaN   8661195  2023-09-26 20:56:02.013106  54.727528
# 5254    NaN    NaN      NaN   6297197  2023-09-26 20:56:02.013106  54.727356
# 5255    NaN    NaN      NaN   8753471  2023-09-26 20:56:02.013106  54.805300
# 5256    NaN    NaN      NaN   7887775  2023-09-26 20:56:02.013106  54.737904
# 5257    NaN    NaN      NaN   6558828  2023-09-26 20:56:02.013106  54.566658
#
#             lon
# 0     20.456526
# 1     56.116150
# 2     55.946445
# 3     58.658596
# 4     55.932686
# ...         ...
# 5253  55.947640
# 5254  55.968070
# 5255  56.036000
# 5256  56.029900
# 5257  55.886185
#
# [5250 rows x 21 columns]

# %%
df1_unique_title[df1_unique_title['title']=='Авиатор, гостиница']
# Out:
# Empty DataFrame
# Columns: [id, create_time, title, hotel_type_original, city, address, rating, rating_5, review_count, region, star_rating, rooms_count, contact_social, description, email, phone, website, uid, parsing_time, lat, lon]
# Index: []
#
# [0 rows x 21 columns]

# %%
df1_unique_title.title.nunique()
# Out:
# 5250

# %% [markdown]
# В данных с первой платформы присутствуют данные о 5250 гостиницах, которых нет в данных из второй платформы

# %%
df1_df2_onli_title = df1[(df1['title'].isin(df2_title))]
df1_df2_onli_title
# Out:
#          id                 create_time                        title  \
# 8     85902  2023-09-26 15:00:20.095657        AZIMUT Сити Отель Уфа
# 470   86409  2023-09-26 15:02:09.620558                 Villa Blanca
# 505   86446  2023-09-26 15:02:17.535145  Малый отель на Черниковской
# 664   86618  2023-09-26 15:02:54.225804                   Купеческая
# 1092  87060  2023-09-26 15:04:27.122644                   Вечный зов
# 1106  87076  2023-09-26 15:04:30.518579                          Уют
# 1213  87185  2023-09-26 15:04:53.206990                    Жемчужина
# 2769  83324  2023-09-26 14:51:04.602064                  Апартаменты
#
#        hotel_type_original              city  \
# 8                    Hotel               Уфа
# 470   Villas_and_Bungalows    Зелёная Поляна
# 505                  Hotel               Уфа
# 664                  Hotel  Николо-Берёзовка
# 1092                 Hotel        Месягутово
# 1106            Mini-hotel          Чекмагуш
# 1213                 Hotel               Уфа
# 2769             Apartment       Калининград
#
#                                                 address  rating  rating_5  \
# 8                              пр-т Октября, д. 81, Уфа     8.7      4.35
# 470   Russia, Republic of Bashkortostan, Zelenaya Po...     8.1      4.05
# 505                       Черниковская улица, д.51, Уфа     8.9      4.45
# 664                    ул. Ленина, 59, Николо-Берёзовка     0.0      0.00
# 1092                   ул. Промышленная, 20, Месягутово     0.0      0.00
# 1106                           ул. Ленина, 21, Чекмагуш     0.0      0.00
# 1213                          ул. Мечникова, 101/1, Уфа     0.0      0.00
# 2769         Васильково, ул. Весенняя д. 1, Калининград    10.0      5.00
#
#       review_count  region  ...  rooms_count  contact_social  description  \
# 8              988       2  ...        190.0             NaN          NaN
# 470              0       2  ...          NaN             NaN          NaN
# 505              0       2  ...         11.0             NaN          NaN
# 664              0       2  ...         11.0             NaN          NaN
# 1092             0       2  ...          NaN             NaN          NaN
# 1106             0       2  ...          NaN             NaN          NaN
# 1213             0       2  ...          NaN             NaN          NaN
# 2769             0       2  ...          NaN             NaN          NaN
#
#       email  phone  website       uid                parsing_time        lat  \
# 8       NaN    NaN      NaN   7403650  2023-09-26 20:56:02.013106  54.774017
# 470     NaN    NaN      NaN   9085625  2023-09-26 20:56:02.013106  53.602097
# 505     NaN    NaN      NaN   9986702  2023-09-26 20:56:02.013106  54.807750
# 664     NaN    NaN      NaN   8854135  2023-09-26 20:56:02.013106  56.126396
# 1092    NaN    NaN      NaN   9245042  2023-09-26 20:56:02.013106  55.556858
# 1106    NaN    NaN      NaN   8875908  2023-09-26 20:56:02.013106  55.148210
# 1213    NaN    NaN      NaN   8875687  2023-09-26 20:56:02.013106  54.817017
# 2769    NaN    NaN      NaN  10014909  2023-09-26 20:56:02.013106  54.747944
#
#             lon
# 8     56.025784
# 470   58.620476
# 505   56.118340
# 664   54.148594
# 1092  58.262875
# 1106  54.644077
# 1213  56.197220
# 2769  20.578830
#
# [8 rows x 21 columns]

# %%
df2_df1_onli_title = df2[df2['title'].isin(df1_df2_onli_title.title.unique())]
df2_df1_onli_title
# Out:
#         id                 create_time                        title  \
# 95   49379  2023-09-19 21:44:17.255943                 Villa Blanca
# 101  49463  2023-09-19 21:44:39.015675                  Апартаменты
# 120  49523  2023-09-19 21:44:53.924128                   Купеческая
# 148  49639  2023-09-19 21:45:22.300896                    Жемчужина
# 294  49426  2023-09-19 21:44:29.707488  Малый отель на Черниковской
# 328  67689  2023-09-29 15:26:35.076860                   Вечный зов
# 389  49694  2023-09-19 21:45:35.500098                          Уют
# 409  49335  2023-09-19 21:44:03.583678        AZIMUT Сити Отель Уфа
#
#     hotel_type_original          city  \
# 95                hotel  magnitogorsk
# 101               hotel  magnitogorsk
# 120               hotel       izhevsk
# 148               hotel           NaN
# 294               hotel           ufa
# 328               hotel           NaN
# 389               hotel           NaN
# 409               hotel           ufa
#
#                                                address  rating  rating_5  \
# 95   Россия, Республика Башкортостан, Абзелиловский...     4.9       4.9
# 101  Россия, Республика Башкортостан, Абзелиловский...     5.0       5.0
# 120  Россия, Республика Башкортостан, Краснокамский...     5.0       5.0
# 148  Россия, Республика Башкортостан, Гафурийский р...     NaN       NaN
# 294  Россия, Республика Башкортостан, Уфа городской...     4.7       4.7
# 328  Россия, Республика Башкортостан, Дуванский рай...     NaN       NaN
# 389  Россия, Республика Башкортостан, Бижбулякский ...     NaN       NaN
# 409  Россия, Республика Башкортостан, Уфа городской...     4.1       4.1
#
#      review_count  region  ...  \
# 95           62.0       2  ...
# 101           4.0       2  ...
# 120           8.0       2  ...
# 148           NaN       2  ...
# 294          33.0       2  ...
# 328           NaN       2  ...
# 389           NaN       2  ...
# 409         386.0       2  ...
#
#                                         contact_social  description  email  \
# 95   [{"social": "vk", "contact": "https://vk.com/i...          NaN  [nan]
# 101  [{"social": "vk", "contact": "https://vk.com/i...          NaN  [nan]
# 120  [{"social": "vk", "contact": "https://vk.com/g...          NaN  [nan]
# 148  [{"social": "vk", "contact": "https://vk.com/c...          NaN  [nan]
# 294                                                NaN          NaN  [nan]
# 328                                                NaN          NaN  [nan]
# 389                                                NaN          NaN  [nan]
# 409                                                NaN          NaN  [nan]
#
#                                          phone  \
# 95                 [88002016652,  79177426119]
# 101                [79068728826,  88002016652]
# 120                              [73475976735]
# 148                              [79279505922]
# 294                [79871349915,  73472758888]
# 328                              [79373583838]
# 389                              [79174081668]
# 409  [79061002225,  79871349915,  73472359000]
#
#                             website                uid  \
# 95                   villablanca.ru  70000001040793506
# 101                       nedoma.ru  70000001054539010
# 120             Забронировать номер  70000001053073691
# 148                   Забронировать  70000001069849052
# 294                             NaN  70000001024370385
# 328  hotel-vechny-zov.business.site  70000001069494156
# 389                   Забронировать  70000001069869342
# 409                azimuthotels.com   2393065583019852
#
#                    parsing_time        lat        lon  len_phone
# 95   2023-09-20 04:41:47.496957  53.602351  58.620400          2
# 101  2023-09-20 04:42:09.509234  53.596890  58.604559          2
# 120  2023-09-20 04:42:25.488521  56.126403  54.148506          1
# 148  2023-09-20 04:42:56.238668  53.891273  56.498372          1
# 294  2023-09-20 04:41:59.758361  54.807821  56.118155          2
# 328  2023-09-29 22:24:01.066849  55.556866  58.262900          1
# 389  2023-09-20 04:43:10.918102  53.695263  54.255642          1
# 409  2023-09-20 04:41:36.066473  54.773961  56.026270          3
#
# [8 rows x 22 columns]

# %%
df_onli = df1_df2_onli_title.merge(df2_df1_onli_title, on='title')
df_onli.head(2)
# Out:
#     id_x               create_time_x                  title  \
# 0  85902  2023-09-26 15:00:20.095657  AZIMUT Сити Отель Уфа
# 1  86409  2023-09-26 15:02:09.620558           Villa Blanca
#
#   hotel_type_original_x          city_x  \
# 0                 Hotel             Уфа
# 1  Villas_and_Bungalows  Зелёная Поляна
#
#                                            address_x  rating_x  rating_5_x  \
# 0                           пр-т Октября, д. 81, Уфа       8.7        4.35
# 1  Russia, Republic of Bashkortostan, Zelenaya Po...       8.1        4.05
#
#    review_count_x  region_x  ...  \
# 0             988         2  ...
# 1               0         2  ...
#
#                                     contact_social_y  description_y  email_y  \
# 0                                                NaN            NaN    [nan]
# 1  [{"social": "vk", "contact": "https://vk.com/i...            NaN    [nan]
#
#                                      phone_y         website_y  \
# 0  [79061002225,  79871349915,  73472359000]  azimuthotels.com
# 1                [88002016652,  79177426119]    villablanca.ru
#
#                uid_y              parsing_time_y      lat_y     lon_y  \
# 0   2393065583019852  2023-09-20 04:41:36.066473  54.773961  56.02627
# 1  70000001040793506  2023-09-20 04:41:47.496957  53.602351  58.62040
#
#    len_phone
# 0          3
# 1          2
#
# [2 rows x 42 columns]

# %%
df_onli['review_count_all'] = df_onli['review_count_x'] + df_onli['review_count_y']
df_onli = df_onli[['title', 'review_count_all']].sort_values('review_count_all', ascending=False)
df_onli
# Out:
#                          title  review_count_all
# 0        AZIMUT Сити Отель Уфа            1374.0
# 1                 Villa Blanca              62.0
# 2  Малый отель на Черниковской              33.0
# 3                   Купеческая               8.0
# 7                  Апартаменты               4.0
# 4                   Вечный зов               NaN
# 5                          Уют               NaN
# 6                    Жемчужина               NaN

# %%
df_onli.title.unique()
# Out:
# array(['AZIMUT Сити Отель Уфа', 'Villa Blanca',
#        'Малый отель на Черниковской', 'Купеческая', 'Апартаменты',
#        'Вечный зов', 'Уют', 'Жемчужина'], dtype=object)

# %% [markdown]
# Больше всего отзывов у гостиницы, которая есть в данных с обоих платформ под названием "AZIMUT Сити Отель Уфа" их обединенное количество равно 1374 отзыва

# %% [markdown]
# # Выводы

# %% [markdown]
# 1. По каждой платформе собрали финальный список гостиниц, с уникальными именами данные с первой платформы хранятся в датафрейме `df1` в данном датафрейме данные о 5258 гостиницах, со второй платформы в датафрейме `df2`  в данном датафрейме данные о 500 гостиницах.

# %% [markdown]
# 2. данные почищенны

# %% [markdown]
# 3. Поля телефона, email, сайтов расперсены и сохранены как списки в одинаковом формате ( address@domen.org, 79234553322, domen.ru)

# %% [markdown]
# 4. в `df1` данные о телефонах пропущены

# %% [markdown]
# в `df1` данные о топ 10 гостиниц по количеству отзывов:
# - 'Radisson Blu Hotel Kaliningrad',
# - 'AZIMUT Сити Отель Уфа',
# - 'Отель Кайзерхоф (Kaiserhof)',
# - 'Отель Ibis Калининград Центр',
# - 'Hilton Garden Inn Ufa Riverside',
# - 'Отель АМАКС Сити-отель',
# - 'Отель Hampton by Hilton Уфа',
# - 'Гостиничный Комплекс Президент Отель',
# - 'Гостиница Мартон Палас Калининград',
# - 'Гостиница "Шкиперская"'

# %% [markdown]
# в `df2` данные от топ 10 костиницах по номерам телефонов:
# - 'Панорама, мини-отель',
# - 'Goldy Land',
# - 'Ивкор, база отдыха',
# - 'Берлога на озере Калкан, база отдыха',
# - 'Орленок, апарт-отель',
# - 'Сказка, мини-отель',
# - 'La Bereg, гостевой комплекс',
# - 'Добр здравич, гостиница',
# - 'Межгорье, мини-гостиница',
# - 'Шале поляна, отель'

# %% [markdown]
# в `df2` данные о топ 10 гостиниц по количеству отзывов:
# - 'Hilton Garden Inn Ufa Riverside, отель',
# - 'Башкирия, гостиничный комплекс',
# - 'Hampton by hilton Ufa, отель',
# - 'Урал тау, гостиничный комплекс',
# - 'AZIMUT Сити Отель Уфа',
# - 'Амакс Сити-отель, гостиница',
# - 'Президент отель, гостиничный комплекс',
# - 'Sheratonplaza Ufa Congress Hotel, гостиница',
# - 'ВолнаСити, отель',
# - 'Свояк, гостиничный комплекс'

# %% [markdown]
# 5. координаты центра пересечения диагоналей квадрата с наибольшей плотностью гостиниц: lat: 54.95926, lon: 20.489283
# координаты углов квадрата с наибольшей плотностью
# - lat: 54.96376, lon: 20.496983
# - lat: 54.96376, lon: 20.481583
# - lat: 54.95476, lon: 20.496983
# - lat: 54.95476, lon: 20.481583

# %% [markdown]
# все гостиницы, которые есть в платформе 1 и нет в платформе 2 находятся в датафрейме `df1_unique_title` всего таких гостиниц 5250

# %% [markdown]
# Всего в датафрейме есть информация о 8 гостиницах которые есть в датафреймах их обоих платформ в таблицк из них только у 5 есть информация о количестве отзывов:
# - 'AZIMUT Сити Отель Уфа',
# - 'Villa Blanca',
# - 'Малый отель на Черниковской',
# - 'Купеческая',
# - Апартаменты'

# %% [markdown]
# В задаче есть противоречие в данных есть столбец `uid` Уникальный идентификатор гостиницы на платформе, не может быть разным у одной гостиницы, и не может повторятся у разных гостиниц, но в рамках одной платформы, но если смотреть данные о гостинице "Апартаменты на Гагарина" из первой платформы, то мы видим что судя по адресу это данные об одной и той же гостинице, но 	`uid`  у гостиниц отличается.
